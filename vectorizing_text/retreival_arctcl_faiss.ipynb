# %%
# %pip install -U langchain-text-splitters langchain-community langgraph langchain-ollama langchain-chroma unstructured pandas markdown unstructured[md] faiss-cpu faiss-gpu-cu12 langchain_huggingface
# Out:
# Requirement already satisfied: langchain-text-splitters in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.3.6)
# Requirement already satisfied: langchain-community in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.3.19)
# Requirement already satisfied: langgraph in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.3.6)
# Requirement already satisfied: langchain-ollama in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.2.3)
# Requirement already satisfied: langchain-chroma in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.2.2)
# Requirement already satisfied: unstructured in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.16.25)
# Requirement already satisfied: pandas in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: markdown in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (3.7)
# Requirement already satisfied: faiss-cpu in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (1.10.0)
# Requirement already satisfied: faiss-gpu-cu12 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (1.10.0)
# Requirement already satisfied: langchain_huggingface in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-text-splitters) (0.3.43)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langgraph) (2.0.18)
# Requirement already satisfied: langgraph-prebuilt<0.2,>=0.1.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langgraph) (0.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langgraph) (0.1.55)
# Requirement already satisfied: ollama<1,>=0.4.4 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-ollama) (0.4.7)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-chroma) (0.6.3)
# Requirement already satisfied: chardet in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (5.3.1)
# Requirement already satisfied: nltk in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (4.13.3)
# Requirement already satisfied: emoji in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: python-iso639 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (3.12.2)
# Requirement already satisfied: backoff in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (0.31.1)
# Requirement already satisfied: wrapt in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (7.0.0)
# Requirement already satisfied: python-oxmsg in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: packaging in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from faiss-gpu-cu12) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from faiss-gpu-cu12) (12.4.5.8)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain_huggingface) (0.29.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain_huggingface) (3.4.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain_huggingface) (0.21.0)
# Requirement already satisfied: transformers>=4.39.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain_huggingface) (4.49.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: build>=1.0.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.19.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: filelock in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-text-splitters) (1.33)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: torch>=1.11.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.6.0)
# Requirement already satisfied: scikit-learn in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.6.1)
# Requirement already satisfied: scipy in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.15.2)
# Requirement already satisfied: Pillow in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (11.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from transformers>=4.39.0->langchain_huggingface) (0.5.3)
# Requirement already satisfied: soupsieve>1.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: webencodings in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from nltk->unstructured) (8.1.8)
# Requirement already satisfied: joblib in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: olefile in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (44.0.2)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pypdf>=4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (5.3.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (0.4.0)
# Requirement already satisfied: pyproject_hooks in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.46.1)
# Requirement already satisfied: anyio in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: coloredlogs in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.29.3)
# Requirement already satisfied: sympy in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.69.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: distro>=1.5.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.19.1)
# Requirement already satisfied: networkx in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.2.0)
# Requirement already satisfied: setuptools in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (76.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: pycparser in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: zipp>=3.20 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="Snowflake/snowflake-arctic-embed-l-v2.0")

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(embedding_function=embeddings, index=index, docstore=InMemoryDocstore(), index_to_docstore_id={})

# %% [markdown]
# ### Vectorizing Documents

# %%
# This is a small test
import os
import glob
import re
import json
from typing import List
import torch
import pandas as pd

from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain_core.documents import Document

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

def process_markdown_file(filepath: str, textbooks_df, special_chapters_df) -> List[Document]:
    # Get folder name from file path
    folder_name = os.path.basename(os.path.dirname(filepath))
    
    # Parse folder name to extract subject code, grade, and chapter code
    parts = folder_name.split('_')
    
    if len(parts) < 3:
        print(f"Warning: Folder name '{folder_name}' doesn't match expected format.")
        parsed_info = None
    
    subject_code = parts[0]
    grade = parts[1]
    chapter_code = '_'.join(parts[2:]) if len(parts) > 3 else parts[2]

    parsed_info = {
        "grade": grade,
        "subject_code": subject_code,
        "chapter_code": chapter_code
    }

    if not parsed_info:
        return []
    
    grade = parsed_info["grade"]
    subject_code = parsed_info["subject_code"]
    chapter_code = parsed_info["chapter_code"]
    
    # Look up subject name and textbook
    subject_info = textbooks_df[
        (textbooks_df['grade'] == int(grade)) & 
        (textbooks_df['subjectcode'] == subject_code)
    ]
    
    if subject_info.empty:
        print(f"Warning: No subject info found for grade {grade}, subject code {subject_code}")
        subject_name = subject_code
        textbook_name = "Unknown"
    else:
        subject_name = subject_info['subjectname'].iloc[0]
        textbook_name = subject_info['textbook'].iloc[0]
    
    # Format chapter title
    # Check if this is a special chapter
    chapter_title = chapter_code
    
    match = re.match(r'([a-zA-Z]+)(\d+)', chapter_code)
    if match:
        letter_code = match.group(1)
        number = match.group(2)
        
        # Look up special chapter in dataframe
        special_chapter = special_chapters_df[
            (special_chapters_df['grade'] == int(grade)) & 
            (special_chapters_df['subjectcode'] == subject_code) & 
            (special_chapters_df['special_chaptercode'] == letter_code)
        ]
        
        if not special_chapter.empty:
            chapter_type = special_chapter['chaptertype'].iloc[0]
            chapter_title = f"{chapter_type} {number}"
    
    # If it's just a number or didn't match any special chapter
    if chapter_code.isdigit():
        chapter_title = f"chapter {chapter_code}"
    
    # Load the markdown file
    loader = TextLoader(filepath)
    documents = loader.load()

    meta_filepath = os.path.join(os.path.dirname(filepath), os.path.basename(filepath).replace('.md', '_meta.json'))
    section_titles = []

    if os.path.exists(meta_filepath):
        with open(meta_filepath, 'r') as f:
            metadata = json.load(f)

            for section in metadata.get('table_of_contents', []):
                title = section.get('title', '')
                section_titles.append(title)

    headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3"), ("####", "Header 4")]

    text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on, strip_headers=False)
    chunks = text_splitter.split_text(documents[0].page_content)
    print(len(chunks), len(section_titles))
    
    # Add metadata to each chunk
    for i, chunk in enumerate(chunks):
        section_title = section_titles[i] if i < len(section_titles) else ""

        chunk.metadata.update({
            "grade": grade,
            "subject_code": subject_code,
            "chapter_code": chapter_code,
            "subject_name": subject_name,
            "textbook_name": textbook_name,
            "chapter_title": chapter_title,
            "section_title": section_title,
            "split_number": i + 1,
            "total_splits": len(chunks),
            "source": filepath
        })
    
    if len(chunks) != len(section_titles):
        print(f"Warning: Number of chunks ({len(chunks)}) doesn't match number of section titles ({len(section_titles)}) for {filepath}")

    return chunks

textbooks_df = pd.read_csv("textbooks.csv")
special_chapters_df = pd.read_csv("special_chapters.csv")

markdown_files = glob.glob(os.path.join("../extracted_text", "**/*.md"), recursive=True)
print(f"Found {len(markdown_files)} markdown files to process")

for file_path in markdown_files:
        print(f"Processing file: {file_path}")
        try:
            torch.cuda.empty_cache()
            chunks = process_markdown_file(file_path, textbooks_df, special_chapters_df)
            vector_store.add_documents(chunks)
            vector_store.save_local("faiss-index")
            print(f"Successfully processed {file_path}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")
            #save these errors file paths in a separate file
            with open("error_files.txt", "a") as f:
                f.write(file_path + "\n")
    
print("Finished processing all markdown files")
# Out:
# Found 790 markdown files to process
# Processing file: ../extracted_text/bio_11_7/bio_11_7.md
# 8 7
# Warning: Number of chunks (8) doesn't match number of section titles (7) for ../extracted_text/bio_11_7/bio_11_7.md
# Successfully processed ../extracted_text/bio_11_7/bio_11_7.md
# Processing file: ../extracted_text/inf_11_8/inf_11_8.md
# 68 68
# Successfully processed ../extracted_text/inf_11_8/inf_11_8.md
# Processing file: ../extracted_text/geo_9_1/geo_9_1.md
# 12 14
# Warning: Number of chunks (12) doesn't match number of section titles (14) for ../extracted_text/geo_9_1/geo_9_1.md
# Successfully processed ../extracted_text/geo_9_1/geo_9_1.md
# Processing file: ../extracted_text/pol_12_1/pol_12_1.md
# 20 28
# Warning: Number of chunks (20) doesn't match number of section titles (28) for ../extracted_text/pol_12_1/pol_12_1.md
# Successfully processed ../extracted_text/pol_12_1/pol_12_1.md
# Processing file: ../extracted_text/sci_9_3/sci_9_3.md
# 34 34
# Successfully processed ../extracted_text/sci_9_3/sci_9_3.md
# Processing file: ../extracted_text/math_11_3/math_11_3.md
# 20 23
# Warning: Number of chunks (20) doesn't match number of section titles (23) for ../extracted_text/math_11_3/math_11_3.md
# Error processing ../extracted_text/math_11_3/math_11_3.md: CUDA out of memory. Tried to allocate 762.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 765.69 MiB is free. Including non-PyTorch memory, this process has 5.03 GiB memory in use. Of the allocated memory 4.03 GiB is allocated by PyTorch, and 916.30 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english2_8_2/english2_8_2.md
# 8 8
# Successfully processed ../extracted_text/english2_8_2/english2_8_2.md
# Processing file: ../extracted_text/math_10_6/math_10_6.md
# 10 12
# Warning: Number of chunks (10) doesn't match number of section titles (12) for ../extracted_text/math_10_6/math_10_6.md
# Successfully processed ../extracted_text/math_10_6/math_10_6.md
# Processing file: ../extracted_text/math_8_13/math_8_13.md
# 20 20
# Successfully processed ../extracted_text/math_8_13/math_8_13.md
# Processing file: ../extracted_text/phy_11_4/phy_11_4.md
# 30 29
# Warning: Number of chunks (30) doesn't match number of section titles (29) for ../extracted_text/phy_11_4/phy_11_4.md
# Error processing ../extracted_text/phy_11_4/phy_11_4.md: CUDA out of memory. Tried to allocate 1002.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 905.69 MiB is free. Including non-PyTorch memory, this process has 4.89 GiB memory in use. Of the allocated memory 4.27 GiB is allocated by PyTorch, and 536.69 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/pe_10_4/pe_10_4.md
# 33 38
# Warning: Number of chunks (33) doesn't match number of section titles (38) for ../extracted_text/pe_10_4/pe_10_4.md
# Successfully processed ../extracted_text/pe_10_4/pe_10_4.md
# Processing file: ../extracted_text/ict_9_1/ict_9_1.md
# 16 16
# Successfully processed ../extracted_text/ict_9_1/ict_9_1.md
# Processing file: ../extracted_text/home_11_1/home_11_1.md
# 7 6
# Warning: Number of chunks (7) doesn't match number of section titles (6) for ../extracted_text/home_11_1/home_11_1.md
# Successfully processed ../extracted_text/home_11_1/home_11_1.md
# Processing file: ../extracted_text/phy_11_3/phy_11_3.md
# 25 24
# Warning: Number of chunks (25) doesn't match number of section titles (24) for ../extracted_text/phy_11_3/phy_11_3.md
# Error processing ../extracted_text/phy_11_3/phy_11_3.md: CUDA out of memory. Tried to allocate 908.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 815.69 MiB is free. Including non-PyTorch memory, this process has 4.98 GiB memory in use. Of the allocated memory 4.58 GiB is allocated by PyTorch, and 304.05 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english2_8_1/english2_8_1.md
# 6 6
# Successfully processed ../extracted_text/english2_8_1/english2_8_1.md
# Processing file: ../extracted_text/psy_11_2/psy_11_2.md
# 39 38
# Warning: Number of chunks (39) doesn't match number of section titles (38) for ../extracted_text/psy_11_2/psy_11_2.md
# Successfully processed ../extracted_text/psy_11_2/psy_11_2.md
# Processing file: ../extracted_text/english_11_p11/english_11_p11.md
# 6 5
# Warning: Number of chunks (6) doesn't match number of section titles (5) for ../extracted_text/english_11_p11/english_11_p11.md
# Successfully processed ../extracted_text/english_11_p11/english_11_p11.md
# Processing file: ../extracted_text/phy_12_2/phy_12_2.md
# 44 59
# Warning: Number of chunks (44) doesn't match number of section titles (59) for ../extracted_text/phy_12_2/phy_12_2.md
# Error processing ../extracted_text/phy_12_2/phy_12_2.md: CUDA out of memory. Tried to allocate 818.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 763.69 MiB is free. Including non-PyTorch memory, this process has 5.03 GiB memory in use. Of the allocated memory 4.01 GiB is allocated by PyTorch, and 943.12 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english2_11_r1/english2_11_r1.md
# 13 13
# Successfully processed ../extracted_text/english2_11_r1/english2_11_r1.md
# Processing file: ../extracted_text/math_10_11/math_10_11.md
# 5 4
# Warning: Number of chunks (5) doesn't match number of section titles (4) for ../extracted_text/math_10_11/math_10_11.md
# Successfully processed ../extracted_text/math_10_11/math_10_11.md
# Processing file: ../extracted_text/pol_12_3/pol_12_3.md
# 13 15
# Warning: Number of chunks (13) doesn't match number of section titles (15) for ../extracted_text/pol_12_3/pol_12_3.md
# Successfully processed ../extracted_text/pol_12_3/pol_12_3.md
# Processing file: ../extracted_text/history_12_5/history_12_5.md
# 60 70
# Warning: Number of chunks (60) doesn't match number of section titles (70) for ../extracted_text/history_12_5/history_12_5.md
# Successfully processed ../extracted_text/history_12_5/history_12_5.md
# Processing file: ../extracted_text/history_8_4/history_8_4.md
# 24 24
# Successfully processed ../extracted_text/history_8_4/history_8_4.md
# Processing file: ../extracted_text/geo3_11_1/geo3_11_1.md
# 6 6
# Successfully processed ../extracted_text/geo3_11_1/geo3_11_1.md
# Processing file: ../extracted_text/geo_9_6/geo_9_6.md
# 16 15
# Warning: Number of chunks (16) doesn't match number of section titles (15) for ../extracted_text/geo_9_6/geo_9_6.md
# Successfully processed ../extracted_text/geo_9_6/geo_9_6.md
# Processing file: ../extracted_text/civics_10_5/civics_10_5.md
# 14 14
# Successfully processed ../extracted_text/civics_10_5/civics_10_5.md
# Processing file: ../extracted_text/math_9_11/math_9_11.md
# 10 13
# Warning: Number of chunks (10) doesn't match number of section titles (13) for ../extracted_text/math_9_11/math_9_11.md
# Successfully processed ../extracted_text/math_9_11/math_9_11.md
# Processing file: ../extracted_text/acc_12_4/acc_12_4.md
# 60 69
# Warning: Number of chunks (60) doesn't match number of section titles (69) for ../extracted_text/acc_12_4/acc_12_4.md
# Error processing ../extracted_text/acc_12_4/acc_12_4.md: CUDA out of memory. Tried to allocate 1.18 GiB. GPU 0 has a total capacity of 5.79 GiB of which 121.69 MiB is free. Including non-PyTorch memory, this process has 5.66 GiB memory in use. Of the allocated memory 5.33 GiB is allocated by PyTorch, and 233.68 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/chem_12_1/chem_12_1.md
# 23 22
# Warning: Number of chunks (23) doesn't match number of section titles (22) for ../extracted_text/chem_12_1/chem_12_1.md
# Error processing ../extracted_text/chem_12_1/chem_12_1.md: CUDA out of memory. Tried to allocate 812.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 761.69 MiB is free. Including non-PyTorch memory, this process has 5.04 GiB memory in use. Of the allocated memory 4.35 GiB is allocated by PyTorch, and 602.09 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english_12_p3/english_12_p3.md
# 5 4
# Warning: Number of chunks (5) doesn't match number of section titles (4) for ../extracted_text/english_12_p3/english_12_p3.md
# Successfully processed ../extracted_text/english_12_p3/english_12_p3.md
# Processing file: ../extracted_text/english2_12_pr5/english2_12_pr5.md
# 14 19
# Warning: Number of chunks (14) doesn't match number of section titles (19) for ../extracted_text/english2_12_pr5/english2_12_pr5.md
# Error processing ../extracted_text/english2_12_pr5/english2_12_pr5.md: CUDA out of memory. Tried to allocate 886.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 713.69 MiB is free. Including non-PyTorch memory, this process has 5.08 GiB memory in use. Of the allocated memory 4.46 GiB is allocated by PyTorch, and 535.03 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/pol2_12_6/pol2_12_6.md
# 20 22
# Warning: Number of chunks (20) doesn't match number of section titles (22) for ../extracted_text/pol2_12_6/pol2_12_6.md
# Error processing ../extracted_text/pol2_12_6/pol2_12_6.md: CUDA out of memory. Tried to allocate 852.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 447.69 MiB is free. Including non-PyTorch memory, this process has 5.34 GiB memory in use. Of the allocated memory 4.30 GiB is allocated by PyTorch, and 960.75 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/eco_12_5/eco_12_5.md
# 17 17
# Error processing ../extracted_text/eco_12_5/eco_12_5.md: CUDA out of memory. Tried to allocate 890.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 661.69 MiB is free. Including non-PyTorch memory, this process has 5.13 GiB memory in use. Of the allocated memory 4.49 GiB is allocated by PyTorch, and 557.48 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/art_11_6/art_11_6.md
# 14 15
# Warning: Number of chunks (14) doesn't match number of section titles (15) for ../extracted_text/art_11_6/art_11_6.md
# Error processing ../extracted_text/art_11_6/art_11_6.md: CUDA out of memory. Tried to allocate 904.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 673.69 MiB is free. Including non-PyTorch memory, this process has 5.12 GiB memory in use. Of the allocated memory 4.50 GiB is allocated by PyTorch, and 536.22 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/geo2_12_1/geo2_12_1.md
# 36 37
# Warning: Number of chunks (36) doesn't match number of section titles (37) for ../extracted_text/geo2_12_1/geo2_12_1.md
# Successfully processed ../extracted_text/geo2_12_1/geo2_12_1.md
# Processing file: ../extracted_text/bus_11_6/bus_11_6.md
# 28 27
# Warning: Number of chunks (28) doesn't match number of section titles (27) for ../extracted_text/bus_11_6/bus_11_6.md
# Successfully processed ../extracted_text/bus_11_6/bus_11_6.md
# Processing file: ../extracted_text/english2_11_w2/english2_11_w2.md
# 4 3
# Warning: Number of chunks (4) doesn't match number of section titles (3) for ../extracted_text/english2_11_w2/english2_11_w2.md
# Successfully processed ../extracted_text/english2_11_w2/english2_11_w2.md
# Processing file: ../extracted_text/geo_9_5/geo_9_5.md
# 15 14
# Warning: Number of chunks (15) doesn't match number of section titles (14) for ../extracted_text/geo_9_5/geo_9_5.md
# Successfully processed ../extracted_text/geo_9_5/geo_9_5.md
# Processing file: ../extracted_text/civics_9_1/civics_9_1.md
# 20 21
# Warning: Number of chunks (20) doesn't match number of section titles (21) for ../extracted_text/civics_9_1/civics_9_1.md
# Successfully processed ../extracted_text/civics_9_1/civics_9_1.md
# Processing file: ../extracted_text/english2_10_9/english2_10_9.md
# 11 12
# Warning: Number of chunks (11) doesn't match number of section titles (12) for ../extracted_text/english2_10_9/english2_10_9.md
# Error processing ../extracted_text/english2_10_9/english2_10_9.md: CUDA out of memory. Tried to allocate 764.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which
00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 549.69 MiB is free. Including non-PyTorch memory, this process has 5.24 GiB memory in use. Of the allocated memory 4.19 GiB is allocated by PyTorch, and 976.92 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/phy_12_5/phy_12_5.md
# 26 28
# Warning: Number of chunks (26) doesn't match number of section titles (28) for ../extracted_text/phy_12_5/phy_12_5.md
# Successfully processed ../extracted_text/phy_12_5/phy_12_5.md
# Processing file: ../extracted_text/english3_12_6/english3_12_6.md
# 7 6
# Warning: Number of chunks (7) doesn't match number of section titles (6) for ../extracted_text/english3_12_6/english3_12_6.md
# Successfully processed ../extracted_text/english3_12_6/english3_12_6.md
# Processing file: ../extracted_text/geo3_11_6/geo3_11_6.md
# 29 31
# Warning: Number of chunks (29) doesn't match number of section titles (31) for ../extracted_text/geo3_11_6/geo3_11_6.md
# Successfully processed ../extracted_text/geo3_11_6/geo3_11_6.md
# Processing file: ../extracted_text/english3_10_3/english3_10_3.md
# 22 24
# Warning: Number of chunks (22) doesn't match number of section titles (24) for ../extracted_text/english3_10_3/english3_10_3.md
# Successfully processed ../extracted_text/english3_10_3/english3_10_3.md
# Processing file: ../extracted_text/history_8_8/history_8_8.md
# 37 39
# Warning: Number of chunks (37) doesn't match number of section titles (39) for ../extracted_text/history_8_8/history_8_8.md
# Successfully processed ../extracted_text/history_8_8/history_8_8.md
# Processing file: ../extracted_text/math_11_8/math_11_8.md
# 12 17
# Warning: Number of chunks (12) doesn't match number of section titles (17) for ../extracted_text/math_11_8/math_11_8.md
# Successfully processed ../extracted_text/math_11_8/math_11_8.md
# Processing file: ../extracted_text/math_12_5/math_12_5.md
# 24 35
# Warning: Number of chunks (24) doesn't match number of section titles (35) for ../extracted_text/math_12_5/math_12_5.md
# Error processing ../extracted_text/math_12_5/math_12_5.md: CUDA out of memory. Tried to allocate 2.14 GiB. GPU 0 has a total capacity of 5.79 GiB of which 275.69 MiB is free. Including non-PyTorch memory, this process has 5.51 GiB memory in use. Of the allocated memory 4.89 GiB is allocated by PyTorch, and 533.75 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english2_10_2/english2_10_2.md
# 5 5
# Successfully processed ../extracted_text/english2_10_2/english2_10_2.md
# Processing file: ../extracted_text/kno_11_2/kno_11_2.md
# 20 21
# Warning: Number of chunks (20) doesn't match number of section titles (21) for ../extracted_text/kno_11_2/kno_11_2.md
# Successfully processed ../extracted_text/kno_11_2/kno_11_2.md
# Processing file: ../extracted_text/bus_12_5/bus_12_5.md
# 42 46
# Warning: Number of chunks (42) doesn't match number of section titles (46) for ../extracted_text/bus_12_5/bus_12_5.md
# Successfully processed ../extracted_text/bus_12_5/bus_12_5.md
# Processing file: ../extracted_text/english_10_3/english_10_3.md
# 16 28
# Warning: Number of chunks (16) doesn't match number of section titles (28) for ../extracted_text/english_10_3/english_10_3.md
# Successfully processed ../extracted_text/english_10_3/english_10_3.md
# Processing file: ../extracted_text/math_12_4/math_12_4.md
# 25 31
# Warning: Number of chunks (25) doesn't match number of section titles (31) for ../extracted_text/math_12_4/math_12_4.md
# Error processing ../extracted_text/math_12_4/math_12_4.md: CUDA out of memory. Tried to allocate 1.21 GiB. GPU 0 has a total capacity of 5.79 GiB of which 107.69 MiB is free. Including non-PyTorch memory, this process has 5.67 GiB memory in use. Of the allocated memory 5.35 GiB is allocated by PyTorch, and 226.94 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text
MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/sci_10_9/sci_10_9.md
# 48 51
# Warning: Number of chunks (48) doesn't match number of section titles (51) for ../extracted_text/sci_10_9/sci_10_9.md
# Successfully processed ../extracted_text/sci_10_9/sci_10_9.md
# Processing file: ../extracted_text/acc_11_5/acc_11_5.md
# 52 54
# Warning: Number of chunks (52) doesn't match number of section titles (54) for ../extracted_text/acc_11_5/acc_11_5.md
# Error processing ../extracted_text/acc_11_5/acc_11_5.md: CUDA out of memory. Tried to allocate 1.25 GiB. GPU 0 has a total capacity of 5.79 GiB of which 1.21 GiB is free. Including non-PyTorch memory, this process has 4.57 GiB memory in use. Of the allocated memory 3.94 GiB is allocated by PyTorch, and 532.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/geo_10_6/geo_10_6.md
# 20 25
# Warning: Number of chunks (20) doesn't match number of section titles (25) for ../extracted_text/geo_10_6/geo_10_6.md
# Successfully processed ../extracted_text/geo_10_6/geo_10_6.md
# Processing file: ../extracted_text/eco_11_3/eco_11_3.md
# 20 19
# Warning: Number of chunks (20) doesn't match number of section titles (19) for ../extracted_text/eco_11_3/eco_11_3.md
# Successfully processed ../extracted_text/eco_11_3/eco_11_3.md
# Processing file: ../extracted_text/comp_11_6/comp_11_6.md
# 36 39
# Warning: Number of chunks (36) doesn't match number of section titles (39) for ../extracted_text/comp_11_6/comp_11_6.md
# Successfully processed ../extracted_text/comp_11_6/comp_11_6.md
# Processing file: ../extracted_text/history_12_12/history_12_12.md
# 47 60
# Warning: Number of chunks (47) doesn't match number of section titles (60) for ../extracted_text/history_12_12/history_12_12.md
# Successfully processed ../extracted_text/history_12_12/history_12_12.md
# Processing file: ../extracted_text/sci_9_1/sci_9_1.md
# 40 44
# Warning: Number of chunks (40) doesn't match number of section titles (44) for ../extracted_text/sci_9_1/sci_9_1.md
# Successfully processed ../extracted_text/sci_9_1/sci_9_1.md
# Processing file: ../extracted_text/history_11_7/history_11_7.md
# 49 61
# Warning: Number of chunks (49) doesn't match number of section titles (61) for ../extracted_text/history_11_7/history_11_7.md
# Successfully processed ../extracted_text/history_11_7/history_11_7.md
# Processing file: ../extracted_text/eco2_12_6/eco2_12_6.md
# 28 30
# Warning: Number of chunks (28) doesn't match number of section titles (30) for ../extracted_text/eco2_12_6/eco2_12_6.md
# Error processing ../extracted_text/eco2_12_6/eco2_12_6.md: CUDA out of memory. Tried to allocate 2.69 GiB. GPU 0 has a total capacity of 5.79 GiB of which 2.32 GiB is free. Including non-PyTorch memory, this process has 3.46 GiB memory in use. Of the allocated memory 2.84 GiB is allocated by PyTorch, and 528.71 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/art_11_4/art_11_4.md
# 15 18
# Warning: Number of chunks (15) doesn't match number of section titles (18) for ../extracted_text/art_11_4/art_11_4.md
# Successfully processed ../extracted_text/art_11_4/art_11_4.md
# Processing file: ../extracted_text/chem_11_1/chem_11_1.md
# 80 79
# Warning: Number of chunks (80) doesn't match number of section titles (79) for ../extracted_text/chem_11_1/chem_11_1.md
# Error processing ../extracted_text/chem_11_1/chem_11_1.md: CUDA out of memory. Tried to allocate 1.13 GiB. GPU 0 has a total capacity of 5.79 GiB of which 833.69 MiB is free. Including non-PyTorch memory, this process has 4.96 GiB memory in use. Of the allocated memory 4.63 GiB is allocated by PyTorch, and 243.50 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text
# 45 44
# Warning: Number of chunks (45) doesn't match number of section titles (44) for ../extracted_text/psy_11_5/psy_11_5.md
# Successfully processed ../extracted_text/psy_11_5/psy_11_5.md
# Processing file: ../extracted_text/soc_12_5/soc_12_5.md
# 30 33
# Warning: Number of chunks (30) doesn't match number of section titles (33) for ../extracted_text/soc_12_5/soc_12_5.md
# Successfully processed ../extracted_text/soc_12_5/soc_12_5.md
# Processing file: ../extracted_text/sci_10_6/sci_10_6.md
# 19 18
# Warning: Number of chunks (19) doesn't match number of section titles (18) for ../extracted_text/sci_10_6/sci_10_6.md
# Successfully processed ../extracted_text/sci_10_6/sci_10_6.md
# Processing file: ../extracted_text/history_8_5/history_8_5.md
# 22 22
# Successfully processed ../extracted_text/history_8_5/history_8_5.md
# Processing file: ../extracted_text/geo_10_7/geo_10_7.md
# 15 22
# Warning: Number of chunks (15) doesn't match number of section titles (22) for ../extracted_text/geo_10_7/geo_10_7.md
# Successfully processed ../extracted_text/geo_10_7/geo_10_7.md
# Processing file: ../extracted_text/inf_12_3/inf_12_3.md
# 54 50
# Warning: Number of chunks (54) doesn't match number of section titles (50) for ../extracted_text/inf_12_3/inf_12_3.md
# Error processing ../extracted_text/inf_12_3/inf_12_3.md: CUDA out of memory. Tried to allocate 1.19 GiB. GPU 0 has a total capacity of 5.79 GiB of which 697.69 MiB is free. Including non-PyTorch memory, this process has 5.10 GiB memory in use. Of the allocated memory 4.77 GiB is allocated by PyTorch, and 229.33 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/history_8_1/history_8_1.md
# 19 19
# Successfully processed ../extracted_text/history_8_1/history_8_1.md
# Processing file: ../extracted_text/english_11_e6/english_11_e6.md
# 9 8
# Warning: Number of chunks (9) doesn't match number of section titles (8) for ../extracted_text/english_11_e6/english_11_e6.md
# Successfully processed ../extracted_text/english_11_e6/english_11_e6.md
# Processing file: ../extracted_text/math_8_3/math_8_3.md
# 31 32
# Warning: Number of chunks (31) doesn't match number of section titles (32) for ../extracted_text/math_8_3/math_8_3.md
# Successfully processed ../extracted_text/math_8_3/math_8_3.md
# Processing file: ../extracted_text/english2_11_w1/english2_11_w1.md
# 9 9
# Successfully processed ../extracted_text/english2_11_w1/english2_11_w1.md
# Processing file: ../extracted_text/english2_9_9/english2_9_9.md
# 3 2
# Warning: Number of chunks (3) doesn't match number of section titles (2) for ../extracted_text/english2_9_9/english2_9_9.md
# Successfully processed ../extracted_text/english2_9_9/english2_9_9.md
# Processing file: ../extracted_text/english_9_2/english_9_2.md
# 14 15
# Warning: Number of chunks (14) doesn't match number of section titles (15) for ../extracted_text/english_9_2/english_9_2.md
# Successfully processed ../extracted_text/english_9_2/english_9_2.md
# Processing file: ../extracted_text/eco2_12_2/eco2_12_2.md
# 18 17
# Warning: Number of chunks (18) doesn't match number of section titles (17) for ../extracted_text/eco2_12_2/eco2_12_2.md
# Error processing ../extracted_text/eco2_12_2/eco2_12_2.md: CUDA out of memory. Tried to allocate 844.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 749.69 MiB is free. Including non-PyTorch memory, this process has 5.05 GiB memory in use. Of the allocated memory 4.39 GiB is allocated by PyTorch, and 573.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/biotech_12_2/biotech_12_2.md
# 16 16
# Successfully processed ../extracted_text/biotech_12_2/biotech_12_2.md
# Processing file: ../extracted_text/pol_11_8/pol_11_8.md
# 26 40
# Warning: Number of chunks (26) doesn't match number of section titles (40) for ../extracted_text/pol_11_8/pol_11_8.md
# Successfully processed ../extracted_text/pol_11_8/pol_11_8.md
# Processing file: ../extracted_text/bus_11_2/bus_11_2.md
# 52 51
# Warning: Number of chunks (52) doesn't match number of section titles (51) for ../extracted_text/bus_11_2/bus_11_2.md
# Error processing ../extracted_text/bus_11_2/bus_11_2.md: CUDA out of memory. Tried to allocate 928.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 929.69 MiB is free. Including non-PyTorch memory, this process has 4.87 GiB memory in use. Of the allocated memory 4.06 GiB is allocated by PyTorch, and 723.31 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/eco2_11_2/eco2_11_2.md
# 32 37
# Warning: Number of chunks (32) doesn't match number of section titles (37) for ../extracted_text/eco2_11_2/eco2_11_2.md
# Successfully processed ../extracted_text/eco2_11_2/eco2_11_2.md
# Processing file: ../extracted_text/pe_10_3/pe_10_3.md
# 36 36
# Successfully processed ../extracted_text/pe_10_3/pe_10_3.md
# Processing file: ../extracted_text/comp_12_8/comp_12_8.md
# 42 45
# Warning: Number of chunks (42) doesn't match number of section titles (45) for ../extracted_text/comp_12_8/comp_12_8.md
# Successfully processed ../extracted_text/comp_12_8/comp_12_8.md
# Processing file: ../extracted_text/chem_11_a1/chem_11_a1.md
# 19 23
# Warning: Number of chunks (19) doesn't match number of section titles (23) for ../extracted_text/chem_11_a1/chem_11_a1.md
# Error processing ../extracted_text/chem_11_a1/chem_11_a1.md: CUDA out of memory. Tried to allocate 1.81 GiB. GPU 0 has a total capacity of 5.79 GiB of which 703.69 MiB is free. Including non-PyTorch memory, this process has 5.09 GiB memory in use. Of the allocated memory 4.47 GiB is allocated by PyTorch, and 534.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/kno_11_7/kno_11_7.md
# 33 33
# Error processing ../extracted_text/kno_11_7/kno_11_7.md: CUDA out of memory. Tried to allocate 938.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 899.69 MiB is free. Including non-PyTorch memory, this process has 4.90 GiB memory in use. Of the allocated memory 4.09 GiB is allocated by PyTorch, and 730.02 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/acc_12_2/acc_12_2.md
# 123 133
# Warning: Number of chunks (123) doesn't match number of section titles (133) for ../extracted_text/acc_12_2/acc_12_2.md
# Error processing ../extracted_text/acc_12_2/acc_12_2.md: CUDA out of memory. Tried to allocate 1.20 GiB. GPU 0 has a total capacity of 5.79 GiB of which 673.69 MiB is free. Including non-PyTorch memory, this process has 5.12 GiB memory in use. Of the allocated memory 4.80 GiB is allocated by PyTorch, and 226.82 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/english3_9_8/english3_9_8.md
# 14 14
# Successfully processed ../extracted_text/english3_9_8/english3_9_8.md
# Processing file: ../extracted_text/civics_10_2/civics_10_2.md
# 12 12
# Successfully processed ../extracted_text/civics_10_2/civics_10_2.md
# Processing file: ../extracted_text/math_11_6/math_11_6.md
# 14 20
# Warning: Number of chunks (14) doesn't match number of section titles (20) for ../extracted_text/math_11_6/math_11_6.md
# Error processing ../extracted_text/math_11_6/math_11_6.md: CUDA out of memory. Tried to allocate 1.33 GiB. GPU 0 has a total capacity of 5.79 GiB of which 1.26 GiB is free. Including non-PyTorch memory, this process has 4.52 GiB memory in use. Of the allocated memory 3.89 GiB is allocated by PyTorch, and 534.31 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text
# 4 5
# Warning: Number of chunks (4) doesn't match number of section titles (5) for ../extracted_text/geo_10_a1/geo_10_a1.md
# Successfully processed ../extracted_text/geo_10_a1/geo_10_a1.md
# Processing file: ../extracted_text/soc_11_3/soc_11_3.md
# 39 40
# Warning: Number of chunks (39) doesn't match number of section titles (40) for ../extracted_text/soc_11_3/soc_11_3.md
# Successfully processed ../extracted_text/soc_11_3/soc_11_3.md
# Processing file: ../extracted_text/chem_11_2/chem_11_2.md
# 92 95
# Warning: Number of chunks (92) doesn't match number of section titles (95) for ../extracted_text/chem_11_2/chem_11_2.md
# Error processing ../extracted_text/chem_11_2/chem_11_2.md: CUDA out of memory. Tried to allocate 1.99 GiB. GPU 0 has a total capacity of 5.79 GiB of which 379.69 MiB is free. Including non-PyTorch memory, this process has 5.41 GiB memory in use. Of the allocated memory 4.78 GiB is allocated by PyTorch, and 535.38 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/history_12_8/history_12_8.md
# 56 66
# Warning: Number of chunks (56) doesn't match number of section titles (66) for ../extracted_text/history_12_8/history_12_8.md
# Successfully processed ../extracted_text/history_12_8/history_12_8.md
# Processing file: ../extracted_text/geo3_12_4/geo3_12_4.md
# 21 25
# Warning: Number of chunks (21) doesn't match number of section titles (25) for ../extracted_text/geo3_12_4/geo3_12_4.md
# Successfully processed ../extracted_text/geo3_12_4/geo3_12_4.md
# Processing file: ../extracted_text/pol2_11_5/pol2_11_5.md
# 24 32
# Warning: Number of chunks (24) doesn't match number of section titles (32) for ../extracted_text/pol2_11_5/pol2_11_5.md
# Successfully processed ../extracted_text/pol2_11_5/pol2_11_5.md
# Processing file: ../extracted_text/math_8_6/math_8_6.md
# 16 19
# Warning: Number of chunks (16) doesn't match number of section titles (19) for ../extracted_text/math_8_6/math_8_6.md
# Successfully processed ../extracted_text/math_8_6/math_8_6.md
# Processing file: ../extracted_text/math_10_13/math_10_13.md
# 23 24
# Warning: Number of chunks (23) doesn't match number of section titles (24) for ../extracted_text/math_10_13/math_10_13.md
# Error processing ../extracted_text/math_10_13/math_10_13.md: CUDA out of memory. Tried to allocate 834.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 583.69 MiB is free. Including non-PyTorch memory, this process has 5.21 GiB memory in use. Of the allocated memory 4.18 GiB is allocated by PyTorch, and 950.28 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/pol_12_4/pol_12_4.md
# 21 35
# Warning: Number of chunks (21) doesn't match number of section titles (35) for ../extracted_text/pol_12_4/pol_12_4.md
# Successfully processed ../extracted_text/pol_12_4/pol_12_4.md
# Processing file: ../extracted_text/bio_12_12/bio_12_12.md
# 12 16
# Warning: Number of chunks (12) doesn't match number of section titles (16) for ../extracted_text/bio_12_12/bio_12_12.md
# Successfully processed ../extracted_text/bio_12_12/bio_12_12.md
# Processing file: ../extracted_text/kno_11_4/kno_11_4.md
# 20 21
# Warning: Number of chunks (20) doesn't match number of section titles (21) for ../extracted_text/kno_11_4/kno_11_4.md
# Successfully processed ../extracted_text/kno_11_4/kno_11_4.md
# Processing file: ../extracted_text/phy_12_7/phy_12_7.md
# 19 29
# Warning: Number of chunks (19) doesn't match number of section titles (29) for ../extracted_text/phy_12_7/phy_12_7.md
# Successfully processed ../extracted_text/phy_12_7/phy_12_7.md
# Processing file: ../extracted_text/art_12_2/art_12_2.md
# 17 19
# Warning: Number of chunks (17) doesn't match number of section titles (19) for ../extracted_text/art_12_2/art_12_2.md
# Successfully processed ../extracted_text/art_12_2/art_12_2.md
# Processing file: ../extracted_text/english3_12_4/english3_12_4.md
# 5 5
# Error processing ../extracted_text/english3_12_4/english3_12_4.md: CUDA out of memory. Tried to allocate 1.06 GiB. GPU 0 has a total capacity of 5.79 GiB of which 613.69 MiB is free. Including non-PyTorch memory, this process has 5.18 GiB memory in use. Of the allocated memory 4.82 GiB is allocated by PyTorch, and 260.25 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/bio_11_19/bio_11_19.md
# 19 19
# Successfully processed ../extracted_text/bio_11_19/bio_11_19.md
# Processing file: ../extracted_text/english_11_p5/english_11_p5.md
# 6 5
# Warning: Number of chunks (6) doesn't match number of section titles (5) for ../extracted_text/english_11_p5/english_11_p5.md
# Successfully processed ../extracted_text/english_11_p5/english_11_p5.md
# Processing file: ../extracted_text/bio_11_16/bio_11_16.md
# 12 13
# Warning: Number of chunks (12) doesn't match number of section titles (13) for ../extracted_text/bio_11_16/bio_11_16.md
# Successfully processed ../extracted_text/bio_11_16/bio_11_16.md
# Processing file: ../extracted_text/civics_10_4/civics_10_4.md
# 13 13
# Successfully processed ../extracted_text/civics_10_4/civics_10_4.md
# Processing file: ../extracted_text/eco2_11_1/eco2_11_1.md
# 16 17
# Warning: Number of chunks (16) doesn't match number of section titles (17) for ../extracted_text/eco2_11_1/eco2_11_1.md
# Successfully processed ../extracted_text/eco2_11_1/eco2_11_1.md
# Processing file: ../extracted_text/eco_12_1/eco_12_1.md
# 15 15
# Successfully processed ../extracted_text/eco_12_1/eco_12_1.md
# Processing file: ../extracted_text/acc3_12_2/acc3_12_2.md
# 97 140
# Warning: Number of chunks (97) doesn't match number of section titles (140) for ../extracted_text/acc3_12_2/acc3_12_2.md
# Error processing ../extracted_text/acc3_12_2/acc3_12_2.md: CUDA out of memory. Tried to allocate 1.33 GiB. GPU 0 has a total capacity of 5.79 GiB of which 1.12 GiB is free. Including non-PyTorch memory, this process has 4.66 GiB memory in use. Of the allocated memory 4.04 GiB is allocated by PyTorch, and 532.50 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/chem_11_5/chem_11_5.md
# 83 84
# Warning: Number of chunks (83) doesn't match number of section titles (84) for ../extracted_text/chem_11_5/chem_11_5.md
# Error processing ../extracted_text/chem_11_5/chem_11_5.md: CUDA out of memory. Tried to allocate 940.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 893.69 MiB is free. Including non-PyTorch memory, this process has 4.91 GiB memory in use. Of the allocated memory 4.09 GiB is allocated by PyTorch, and 731.19 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/geo3_12_7/geo3_12_7.md
# 24 28
# Warning: Number of chunks (24) doesn't match number of section titles (28) for ../extracted_text/geo3_12_7/geo3_12_7.md
# Successfully processed ../extracted_text/geo3_12_7/geo3_12_7.md
# Processing file: ../extracted_text/geo_11_5/geo_11_5.md
# 30 32
# Warning: Number of chunks (30) doesn't match number of section titles (32) for ../extracted_text/geo_11_5/geo_11_5.md
# Successfully processed ../extracted_text/geo_11_5/geo_11_5.md
# Processing file: ../extracted_text/sci_10_4/sci_10_4.md
# 50 56
# Warning: Number of chunks (50) doesn't match number of section titles (56) for ../extracted_text/sci_10_4/sci_10_4.md
# Error processing ../extracted_text/sci_10_4/sci_10_4.md: CUDA out of memory. Tried to allocate 842.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 691.69 MiB is free. Including non-PyTorch memory, this process has 5.10 GiB memory in use. Of the allocated memory 4.07 GiB is allocated by PyTorch, and 954.56 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Processing file: ../extracted_text/phy_12_13/phy_12_13.md
# 21 31
# Warning: Number of chunks (21) doesn't match number of section titles (31) for ../extracted_text/phy_12_13/phy_12_13.md
# Successfully processed ../extracted_text/phy_12_13/phy_12_13.md
# Processing file: ../extracted_text/math_10_7/math_10_7.md
# 9 11
# Warning: Number of chunks (9) doesn't match number of section titles (11) for ../extracted_text/math_10_7/math_10_7.md
# Successfully processed ../extracted_text/math_10_7/math_10_7.md
# Processing file: ../extracted_text/english_9_1/english_9_1.md
# 17 18
# Warning: Number of chunks (17) doesn't match number of section titles (18) for ../extracted_text/english_9_1/english_9_1.md
# Successfully processed ../extracted_text/english_9_1/english_9_1.md
# Finished processing all markdown files

# %%
remaining_files = []
with open("error_files.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        lines = line.strip()
        line = line.strip("\n")
        remaining_files.append(line.strip())

def add_chunks_in_batches(chunks):
    for chunk in chunks:
        torch.cuda.empty_cache()
        vector_store.add_documents([chunk])
        vector_store.save_local("faiss-index")

while len(remaining_files) > 0:
    new_remaining_files = []
    print(f"Processing {len(remaining_files)} remaining files")
    for file_path in remaining_files:
        print(f"Processing file: {file_path}")
        try:
            torch.cuda.empty_cache()
            chunks = process_markdown_file(file_path, textbooks_df, special_chapters_df)
            add_chunks_in_batches(chunks)
            # vector_store.add_documents(chunks)
            # vector_store.save_local("faiss-index")
            print(f"Successfully processed {file_path}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")
            new_remaining_files.append(file_path)
    with open("error_files.txt", "w") as f:
        for file_path in new_remaining_files:
            f.write(file_path + "\n")
    remaining_files = new_remaining_files
# Out:
# Processing 32 remaining files
# Processing file: ../extracted_text/english2_12_pr5/english2_12_pr5.md
# 14 19
# Warning: Number of chunks (14) doesn't match number of section titles (19) for ../extracted_text/english2_12_pr5/english2_12_pr5.md
# Successfully processed ../extracted_text/english2_12_pr5/english2_12_pr5.md
# Processing file: ../extracted_text/english2_10_9/english2_10_9.md
# 11 12
# Warning: Number of chunks (11) doesn't match number of section titles (12) for ../extracted_text/english2_10_9/english2_10_9.md
# Successfully processed ../extracted_text/english2_10_9/english2_10_9.md
# Processing file: ../extracted_text/math_12_5/math_12_5.md
# 24 35
# Warning: Number of chunks (24) doesn't match number of section titles (35) for ../extracted_text/math_12_5/math_12_5.md
# Successfully processed ../extracted_text/math_12_5/math_12_5.md
# Processing file: ../extracted_text/english2_12_pr8/english2_12_pr8.md
# 16 17
# Warning: Number of chunks (16) doesn't match number of section titles (17) for ../extracted_text/english2_12_pr8/english2_12_pr8.md
# Successfully processed ../extracted_text/english2_12_pr8/english2_12_pr8.md
# Processing file: ../extracted_text/eco2_12_6/eco2_12_6.md
# 28 30
# Successfully processed ../extracted_text/english3_12_4/english3_12_4.md

# %% [markdown]
# ### Process Query

# %%
retrieved_docs = vector_store.similarity_search_with_relevance_scores("what is integration?", k=100)

for doc in retrieved_docs:
    print(doc[0].metadata)
# Out:
# {'Header 4': 'Introduction IntroductionIntroduction', 'grade': '12', 'subject_code': 'eco', 'chapter_code': '1', 'subject_name': 'Economics', 'textbook_name': 'Introductory Microeconomics', 'chapter_title': 'chapter 1', 'section_title': 'Introduction\n \nIntroductionIntroduction', 'split_number': 1, 'total_splits': 15, 'source': '../extracted_text/eco_12_1/eco_12_1.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 9, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 9, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 9, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**Activity 9.1**', 'Header 3': '**What are Test, Measurement**', 'grade': '11', 'subject_code': 'pe', 'chapter_code': '9', 'subject_name': 'Health and Physical Education', 'textbook_name': 'Health and Physical Education', 'chapter_title': 'chapter 9', 'section_title': 'What are Test, Measurement', 'split_number': 3, 'total_splits': 46, 'source': '../extracted_text/pe_11_9/pe_11_9.md'}
# {'Header 1': 'Introduction **1**', 'grade': '11', 'subject_code': 'home', 'chapter_code': '1', 'subject_name': 'Home Science', 'textbook_name': 'Human Ecology and Family Sciences', 'chapter_title': 'chapter 1', 'section_title': 'Human Ecology and Family Sciences', 'split_number': 2, 'total_splits': 7, 'source': '../extracted_text/home_11_1/home_11_1.md'}
# {'Header 1': 'Introduction **1**', 'grade': '11', 'subject_code': 'home', 'chapter_code': '1', 'subject_name': 'Home Science', 'textbook_name': 'Human Ecology and Family Sciences', 'chapter_title': 'chapter 1', 'section_title': 'Human Ecology and Family Sciences', 'split_number': 2, 'total_splits': 7, 'source': '../extracted_text/home_11_1/home_11_1.md'}
# {'Header 1': 'Introduction **1**', 'grade': '11', 'subject_code': 'home', 'chapter_code': '1', 'subject_name': 'Home Science', 'textbook_name': 'Human Ecology and Family Sciences', 'chapter_title': 'chapter 1', 'section_title': 'Human Ecology and Family Sciences', 'split_number': 2, 'total_splits': 7, 'source': '../extracted_text/home_11_1/home_11_1.md'}
# {'Header 1': 'PSYCHOLOGICAL DISORDERS', 'Header 4': 'Introduction', 'grade': '12', 'subject_code': 'psy', 'chapter_code': '4', 'subject_name': 'Psychology', 'textbook_name': 'Psychology', 'chapter_title': 'chapter 4', 'section_title': 'Introduction', 'split_number': 3, 'total_splits': 36, 'source': '../extracted_text/psy_12_4/psy_12_4.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.2** *Integration using trigonometric identities*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '234 MATHEMATICS', 'split_number': 13, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.2** *Integration using trigonometric identities*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '234 MATHEMATICS', 'split_number': 13, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.2** *Integration using trigonometric identities*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '234 MATHEMATICS', 'split_number': 13, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': '**Introduction to Problem Solving**', 'grade': '11', 'subject_code': 'comp', 'chapter_code': '4', 'subject_name': 'Computer Science', 'textbook_name': 'Computer Science', 'chapter_title': 'chapter 4', 'section_title': 'Introduction to \nProblem Solving', 'split_number': 2, 'total_splits': 34, 'source': '../extracted_text/comp_11_4/comp_11_4.md'}
# {'Header 1': 'Unit Four', 'Header 2': '**Understanding Marginalisation**', 'grade': '8', 'subject_code': 'civics', 'chapter_code': '5', 'subject_name': 'Civics', 'textbook_name': 'Social and Political Life-III', 'chapter_title': 'chapter 5', 'section_title': 'What Does it Mean to be Socially Marginalised?', 'split_number': 4, 'total_splits': 14, 'source': '../extracted_text/civics_8_5/civics_8_5.md'}
# {'Header 1': 'Factorisation', 'Header 3': '12.1 Introduction', 'grade': '8', 'subject_code': 'math', 'chapter_code': '12', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 12', 'section_title': 'Factorisation', 'split_number': 1, 'total_splits': 20, 'source': '../extracted_text/math_8_12/math_8_12.md'}
# {'Header 1': '**Management in the Twenty-first Century**', 'Header 3': '**Objectives**', 'Header 4': '**Coordination**', 'grade': '12', 'subject_code': 'bus', 'chapter_code': '1', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 1', 'section_title': 'Functions', 'split_number': 33, 'total_splits': 36, 'source': '../extracted_text/bus_12_1/bus_12_1.md'}
# {'Header 1': 'Contents', 'Header 4': '**Introduction**', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '6', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 6', 'section_title': 'Introduction', 'split_number': 4, 'total_splits': 36, 'source': '../extracted_text/psy_11_6/psy_11_6.md'}
# {'Header 1': 'Noticing form', 'Header 2': 'Things to do', 'Header 3': 'ABOUT THE UNIT', 'Header 4': 'COMPREHENSION', 'grade': '12', 'subject_code': 'english2', 'chapter_code': 'pr8', 'subject_name': 'English', 'textbook_name': 'Flamingo', 'chapter_title': 'prose 8', 'section_title': 'SUB-THEME', 'split_number': 11, 'total_splits': 16, 'source': '../extracted_text/english2_12_pr8/english2_12_pr8.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.1** *Integration by substitution*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '232 MATHEMATICS', 'split_number': 10, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.1** *Integration by substitution*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '232 MATHEMATICS', 'split_number': 10, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.3 Methods of Integration**', 'Header 3': '**7.3.1** *Integration by substitution*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '232 MATHEMATICS', 'split_number': 10, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': '7.3 Globalisation and the Media', 'Header 3': '**Globalisation and the case of music**', 'grade': '12', 'subject_code': 'soc2', 'chapter_code': '7', 'subject_name': 'Sociology', 'textbook_name': 'Social Change and Development in India', 'chapter_title': 'chapter 7', 'section_title': 'Television', 'split_number': 17, 'total_splits': 36, 'source': '../extracted_text/soc2_12_7/soc2_12_7.md'}
# {'Header 2': '**EXERCISE 7.10**', 'Header 3': '*Summary*', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Remarks', 'split_number': 40, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': 'After reading this chapter, you would be able to:', 'Header 4': 'Introduction', 'grade': '12', 'subject_code': 'psy', 'chapter_code': '1', 'subject_name': 'Psychology', 'textbook_name': 'Psychology', 'chapter_title': 'chapter 1', 'section_title': 'Individual Differences in Human Functioning\nAssessment of Psychological Attributes\nIntelligence', 'split_number': 4, 'total_splits': 42, 'source': '../extracted_text/psy_12_1/psy_12_1.md'}
# {'Header 3': '*Political Theory*', 'grade': '11', 'subject_code': 'pol', 'chapter_code': '6', 'subject_name': 'Political Science', 'textbook_name': 'Political Theory', 'chapter_title': 'chapter 6', 'section_title': 'Citizenship Citizenship', 'split_number': 12, 'total_splits': 20, 'source': '../extracted_text/pol_11_6/pol_11_6.md'}
# {'Header 1': 'Human Dev Human DevHuman Dev Human Dev Human DevHuman Development elopmentelopment elopment', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '3', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 3', 'section_title': 'Chapter3\nAfter reading this chapter, you would be able to', 'split_number': 2, 'total_splits': 28, 'source': '../extracted_text/psy_11_3/psy_11_3.md'}
# {'Header 2': '**Chapter 1:** Introduction', 'grade': '11', 'subject_code': 'biotech', 'chapter_code': '1', 'subject_name': 'Biotechnology', 'textbook_name': 'Biotechnology', 'chapter_title': 'chapter 1', 'section_title': 'Chapter 1:\nIntroduction', 'split_number': 1, 'total_splits': 25, 'source': '../extracted_text/biotech_11_1/biotech_11_1.md'}
# {'Header 1': '1.2 Urbanisation and Industrialisation', 'grade': '12', 'subject_code': 'soc2', 'chapter_code': '1', 'subject_name': 'Sociology', 'textbook_name': 'Social Change and Development in India', 'chapter_title': 'chapter 1', 'section_title': 'Structural Change', 'split_number': 3, 'total_splits': 19, 'source': '../extracted_text/soc2_12_1/soc2_12_1.md'}
# {'Header 1': '**MATHEMATICAL MODELLING**', 'grade': '11', 'subject_code': 'math', 'chapter_code': 'a2', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'appendix 2', 'section_title': 'MATHEMATICAL MODELLING', 'split_number': 1, 'total_splits': 11, 'source': '../extracted_text/math_11_a2/math_11_a2.md'}
# {'Header 1': '**Importance of Coordination**', 'grade': '12', 'subject_code': 'bus', 'chapter_code': '1', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 1', 'section_title': 'Importance of Coordination', 'split_number': 20, 'total_splits': 36, 'source': '../extracted_text/bus_12_1/bus_12_1.md'}
# {'Header 2': '**7.1 Introduction**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '226 MATHEMATICS', 'split_number': 2, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.1 Introduction**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '226 MATHEMATICS', 'split_number': 2, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.1 Introduction**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '226 MATHEMATICS', 'split_number': 2, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': '**An Introduction to Biotechnology Unit I**', 'Header 2': '**1.3.1 Indian biotechnology industry**', 'Header 4': '**1.3.2 Achievements and innovations**', 'grade': '11', 'subject_code': 'biotech', 'chapter_code': '1', 'subject_name': 'Biotechnology', 'textbook_name': 'Biotechnology', 'chapter_title': 'chapter 1', 'section_title': '1.3.1 Indian biotechnology industry', 'split_number': 17, 'total_splits': 25, 'source': '../extracted_text/biotech_11_1/biotech_11_1.md'}
# {'Header 1': '**10.1Protein Informatics**', 'grade': '11', 'subject_code': 'biotech', 'chapter_code': '10', 'subject_name': 'Biotechnology', 'textbook_name': 'Biotechnology', 'chapter_title': 'chapter 10', 'section_title': '10.1Protein Informatics', 'split_number': 2, 'total_splits': 22, 'source': '../extracted_text/biotech_11_10/biotech_11_10.md'}
# {'Header 1': '**Aquifer**', 'Header 2': '**Groundwater Table**', 'Header 4': '**Immigration**', 'grade': '12', 'subject_code': 'geo3', 'chapter_code': 'a1', 'subject_name': 'Geography', 'textbook_name': 'India-People and Economy', 'chapter_title': 'a1', 'section_title': 'Intrusive irrigation', 'split_number': 23, 'total_splits': 35, 'source': '../extracted_text/geo3_12_a1/geo3_12_a1.md'}
# {'Header 1': 'ABOUT THE UNIT', 'Header 3': 'THEME', 'grade': '12', 'subject_code': 'english2', 'chapter_code': 'pr7', 'subject_name': 'English', 'textbook_name': 'Flamingo', 'chapter_title': 'prose 7', 'section_title': 'ABOUT THE UNIT', 'split_number': 12, 'total_splits': 18, 'source': '../extracted_text/english2_12_pr7/english2_12_pr7.md'}
# {'Header 1': 'Introduction', 'Header 4': '**DEVELOPMENT OF LANGUAGE AND LANGUAGE USE**', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '7', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 7', 'section_title': 'Meaning and Nature of Language', 'split_number': 35, 'total_splits': 44, 'source': '../extracted_text/psy_11_7/psy_11_7.md'}
# {'Header 1': 'Internal Trade', 'grade': '11', 'subject_code': 'bus', 'chapter_code': '10', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 10', 'section_title': 'LEARNING OBJECTIVES', 'split_number': 2, 'total_splits': 50, 'source': '../extracted_text/bus_11_10/bus_11_10.md'}
# {'Header 1': 'Nationalism Nationalism', 'grade': '11', 'subject_code': 'pol', 'chapter_code': '7', 'subject_name': 'Political Science', 'textbook_name': 'Political Theory', 'chapter_title': 'chapter 7', 'section_title': 'Shared Political Ideals', 'split_number': 11, 'total_splits': 18, 'source': '../extracted_text/pol_11_7/pol_11_7.md'}
# {'Header 1': '*GEOGRAPHY AS A DISCIPLINE*', 'grade': '11', 'subject_code': 'geo', 'chapter_code': '1', 'subject_name': 'Geography', 'textbook_name': 'Fundamentals of Physical Geography', 'chapter_title': 'chapter 1', 'section_title': 'GEOGRAPHY AS A DISCIPLINE', 'split_number': 2, 'total_splits': 15, 'source': '../extracted_text/geo_11_1/geo_11_1.md'}
# {'grade': '10', 'subject_code': 'sci', 'chapter_code': '13', 'subject_name': 'Science', 'textbook_name': 'Science', 'chapter_title': 'chapter 13', 'section_title': '13.1 ECO-SYSTEM — WHAT ARE ITS COMPONENTS?', 'split_number': 1, 'total_splits': 22, 'source': '../extracted_text/sci_10_13/sci_10_13.md'}
# {'Header 1': '**UNIT VI**', 'Header 2': 'Development Communication And Journalism', 'grade': '12', 'subject_code': 'home', 'chapter_code': '13', 'subject_name': 'Home Science', 'textbook_name': 'Human Ecology and Family Sciences', 'chapter_title': 'chapter 13', 'section_title': 'Development \nCommunication And \nJournalism', 'split_number': 3, 'total_splits': 21, 'source': '../extracted_text/home_12_13/home_12_13.md'}
# {'Header 1': '**Understanding Secularism**', 'Header 3': '**What is Secularism?**', 'Header 4': '**Discuss in class: Can there be different views within the same religion?**', 'grade': '8', 'subject_code': 'civics', 'chapter_code': '2', 'subject_name': 'Civics', 'textbook_name': 'Social and Political Life-III', 'chapter_title': 'chapter 2', 'section_title': 'Why is it Important to Separate Religion\nfrom the State?', 'split_number': 5, 'total_splits': 8, 'source': '../extracted_text/civics_8_2/civics_8_2.md'}
# {'Header 1': '*In this Chapter*', 'grade': '12', 'subject_code': 'comp', 'chapter_code': '7', 'subject_name': 'Computer Science', 'textbook_name': 'Computer Science', 'chapter_title': 'chapter 7', 'section_title': 'In this Chapter', 'split_number': 2, 'total_splits': 33, 'source': '../extracted_text/comp_12_7/comp_12_7.md'}
# {'Header 1': '**CHAPTER** 5', 'Header 2': '**Importance**', 'Header 4': '**Delegation and Decentralisation: A Comparative view**', 'grade': '12', 'subject_code': 'bus', 'chapter_code': '5', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 5', 'section_title': 'Decentralisation : A Strength', 'split_number': 36, 'total_splits': 42, 'source': '../extracted_text/bus_12_5/bus_12_5.md'}
# {'Header 1': 'ThinkingThinking Thinking', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '7', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 7', 'section_title': 'Chapter7\nAfter reading this chapter, you would be able to', 'split_number': 2, 'total_splits': 44, 'source': '../extracted_text/psy_11_7/psy_11_7.md'}
# {'Header 1': '1.2.2 Commutativity', 'grade': '8', 'subject_code': 'math', 'chapter_code': '1', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 1', 'section_title': '1.2.2 Commutativity', 'split_number': 9, 'total_splits': 31, 'source': '../extracted_text/math_8_1/math_8_1.md'}
# {'Header 1': 'CULTURE AND SOCIALISATION', 'grade': '11', 'subject_code': 'soc', 'chapter_code': '4', 'subject_name': 'Sociology', 'textbook_name': 'Introducing Sociology', 'chapter_title': 'chapter 4', 'section_title': '', 'split_number': 2, 'total_splits': 36, 'source': '../extracted_text/soc_11_4/soc_11_4.md'}
# {'Header 1': 'Talking about the Text', 'Header 2': 'Language Work', 'Header 4': 'A. Grammar', 'grade': '12', 'subject_code': 'english', 'chapter_code': 'nf1', 'subject_name': 'English', 'textbook_name': 'Kaleidoscope', 'chapter_title': 'non fiction 1', 'section_title': 'A. Grammar', 'split_number': 10, 'total_splits': 18, 'source': '../extracted_text/english_12_nf1/english_12_nf1.md'}
# {'Header 1': 'Learning LearningLearning', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '5', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 5', 'section_title': 'Chapter5\nAfter reading this chapter, you would be able to', 'split_number': 2, 'total_splits': 45, 'source': '../extracted_text/psy_11_5/psy_11_5.md'}
# {'Header 1': '**4.6 Verifying Algorithms**', 'Header 4': '**Think and Reflect**', 'grade': '11', 'subject_code': 'comp', 'chapter_code': '4', 'subject_name': 'Computer Science', 'textbook_name': 'Computer Science', 'chapter_title': 'chapter 4', 'section_title': 'Think and Reflect', 'split_number': 28, 'total_splits': 34, 'source': '../extracted_text/comp_11_4/comp_11_4.md'}
# {'Header 1': 'International Trade', 'Header 2': 'HISTORY OF INTERNATIONAL TRADE', 'Header 3': 'GATEWAYS OF INTERNATIONAL TRADE', 'grade': '12', 'subject_code': 'geo', 'chapter_code': '8', 'subject_name': 'Geography', 'textbook_name': 'Fundamentals of Human Geography', 'chapter_title': 'chapter 8', 'section_title': '', 'split_number': 12, 'total_splits': 15, 'source': '../extracted_text/geo_12_8/geo_12_8.md'}
# {'Header 3': '**Motivation and Emotion Motivation and Emotion**', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '8', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 8', 'section_title': 'Chapter8\nAfter reading this chapter, you would be able to', 'split_number': 2, 'total_splits': 32, 'source': '../extracted_text/psy_11_8/psy_11_8.md'}
# {'Header 1': '**Growth and Development**', 'Header 2': '**Table 1: Difference between Growth and Development**', 'grade': '11', 'subject_code': 'pe', 'chapter_code': '3', 'subject_name': 'Health and Physical Education', 'textbook_name': 'Health and Physical Education', 'chapter_title': 'chapter 3', 'section_title': 'Factors Affecting Growth and Development', 'split_number': 5, 'total_splits': 41, 'source': '../extracted_text/pe_11_3/pe_11_3.md'}
# {'Header 1': '**The Making of a Global World**', 'grade': '10', 'subject_code': 'history', 'chapter_code': '3', 'subject_name': 'History', 'textbook_name': 'India and the Contemporary World-II', 'chapter_title': 'chapter 3', 'section_title': 'The Making of a Global World', 'split_number': 3, 'total_splits': 48, 'source': '../extracted_text/history_10_3/history_10_3.md'}
# {'Header 1': '**(a) Addition**', 'Header 4': '**(b) Subtraction**', 'grade': '8', 'subject_code': 'math', 'chapter_code': '1', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 1', 'section_title': '6 MATHEMATICS', 'split_number': 14, 'total_splits': 31, 'source': '../extracted_text/math_8_1/math_8_1.md'}
# {'Header 2': '**7.2 Integration as an Inverse Process of Differentiation**', 'Header 3': '**Derivatives Integrals (Anti derivatives)**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '228 MATHEMATICS', 'split_number': 4, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.2 Integration as an Inverse Process of Differentiation**', 'Header 3': '**Derivatives Integrals (Anti derivatives)**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '228 MATHEMATICS', 'split_number': 4, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.2 Integration as an Inverse Process of Differentiation**', 'Header 3': '**Derivatives Integrals (Anti derivatives)**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': '228 MATHEMATICS', 'split_number': 4, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': 'ABOUT THE UNIT', 'Header 3': 'WRITING', 'grade': '12', 'subject_code': 'english2', 'chapter_code': 'pr7', 'subject_name': 'English', 'textbook_name': 'Flamingo', 'chapter_title': 'prose 7', 'section_title': 'NOTICING DISCOURSE LINKERS AND SIGNALLERS', 'split_number': 17, 'total_splits': 18, 'source': '../extracted_text/english2_12_pr7/english2_12_pr7.md'}
# {'Header 1': 'Introduction to Graphs', 'grade': '8', 'subject_code': 'math', 'chapter_code': '13', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 13', 'section_title': 'Introduction to Graphs', 'split_number': 1, 'total_splits': 20, 'source': '../extracted_text/math_8_13/math_8_13.md'}
# {'Header 1': 'Introduction to Graphs', 'grade': '8', 'subject_code': 'math', 'chapter_code': '13', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 13', 'section_title': 'Introduction to Graphs', 'split_number': 1, 'total_splits': 20, 'source': '../extracted_text/math_8_13/math_8_13.md'}
# {'Header 1': 'Introduction to Graphs', 'grade': '8', 'subject_code': 'math', 'chapter_code': '13', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 13', 'section_title': 'Introduction to Graphs', 'split_number': 1, 'total_splits': 20, 'source': '../extracted_text/math_8_13/math_8_13.md'}
# {'Header 1': 'Notes', 'grade': '12', 'subject_code': 'phy', 'chapter_code': '9', 'subject_name': 'Physics', 'textbook_name': 'Physics', 'chapter_title': 'chapter 9', 'section_title': 'Solution', 'split_number': 29, 'total_splits': 29, 'source': '../extracted_text/phy_12_9/phy_12_9.md'}
# {'Header 1': '**Industrialisation in Independent India**', 'grade': '12', 'subject_code': 'soc2', 'chapter_code': '1', 'subject_name': 'Sociology', 'textbook_name': 'Social Change and Development in India', 'chapter_title': 'chapter 1', 'section_title': "How did the planter's live?", 'split_number': 14, 'total_splits': 19, 'source': '../extracted_text/soc2_12_1/soc2_12_1.md'}
# {'Header 1': '**Net migration**', 'grade': '12', 'subject_code': 'geo3', 'chapter_code': 'a1', 'subject_name': 'Geography', 'textbook_name': 'India-People and Economy', 'chapter_title': 'a1', 'section_title': 'Rainwater Harvesting', 'split_number': 29, 'total_splits': 35, 'source': '../extracted_text/geo3_12_a1/geo3_12_a1.md'}
# {'Header 1': 'The Making of a Global World', 'grade': '10', 'subject_code': 'history', 'chapter_code': '3', 'subject_name': 'History', 'textbook_name': 'India and the Contemporary World-II', 'chapter_title': 'chapter 3', 'section_title': 'Source A', 'split_number': 28, 'total_splits': 48, 'source': '../extracted_text/history_10_3/history_10_3.md'}
# {'Header 3': 'Glossary', 'grade': '8', 'subject_code': 'geo', 'chapter_code': '1', 'subject_name': 'Geography', 'textbook_name': 'Resource and Development', 'chapter_title': 'chapter 1', 'section_title': 'Activity', 'split_number': 3, 'total_splits': 20, 'source': '../extracted_text/geo_8_1/geo_8_1.md'}
# {'Header 1': '3 **Two Stories about Flying**', 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '3', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 3', 'section_title': 'Reading Comprehension', 'split_number': 7, 'total_splits': 22, 'source': '../extracted_text/english3_10_3/english3_10_3.md'}
# {'Header 1': '5 **Glimpses of India**', 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '5', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 5', 'section_title': 'Reading Comprehension', 'split_number': 3, 'total_splits': 22, 'source': '../extracted_text/english3_10_5/english3_10_5.md'}
# {'Header 1': '**Reading Comprehension**', 'Header 2': '**Text I**', 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '4', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 4', 'section_title': 'Q.1. Infer the meanings of the following expressions. \nThe first has been done for you as an example.', 'split_number': 7, 'total_splits': 17, 'source': '../extracted_text/english3_10_4/english3_10_4.md'}
# {'Header 1': '8 **The Sermon at Benaras**', 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '8', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 8', 'section_title': 'Reading Comprehension', 'split_number': 3, 'total_splits': 12, 'source': '../extracted_text/english3_10_8/english3_10_8.md'}
# {'Header 1': '7 **Madam rides the Bus**', 'Header 2': "**Let's Begin**", 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '7', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 7', 'section_title': 'Text I', 'split_number': 4, 'total_splits': 17, 'source': '../extracted_text/english3_10_7/english3_10_7.md'}
# {'Header 1': '9 **The Proposal**', 'Header 3': '**Reading Comprehension**', 'grade': '10', 'subject_code': 'english3', 'chapter_code': '9', 'subject_name': 'English', 'textbook_name': 'Words and Expressions 2', 'chapter_title': 'chapter 9', 'section_title': 'Text I', 'split_number': 4, 'total_splits': 20, 'source': '../extracted_text/english3_10_9/english3_10_9.md'}
# {'Header 1': '**Formation of a Company**', 'grade': '11', 'subject_code': 'bus', 'chapter_code': '7', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 7', 'section_title': 'LEARNING OBJECTIVES', 'split_number': 3, 'total_splits': 30, 'source': '../extracted_text/bus_11_7/bus_11_7.md'}
# {'Header 1': '**Communication Networks**', 'Header 3': 'Personal Communication System', 'Header 4': 'Mass Communication System', 'grade': '12', 'subject_code': 'geo3', 'chapter_code': '7', 'subject_name': 'Geography', 'textbook_name': 'India-People and Economy', 'chapter_title': 'chapter 7', 'section_title': '', 'split_number': 20, 'total_splits': 24, 'source': '../extracted_text/geo3_12_7/geo3_12_7.md'}
# {'Header 1': '**6.1 Communication and communication technology**', 'Header 2': 'What is communication?', 'grade': '11', 'subject_code': 'home', 'chapter_code': '6', 'subject_name': 'Home Science', 'textbook_name': 'Human Ecology and Family Sciences', 'chapter_title': 'chapter 6', 'section_title': 'What is communication?', 'split_number': 4, 'total_splits': 21, 'source': '../extracted_text/home_11_6/home_11_6.md'}
# {'Header 1': 'Noticing form', 'Header 3': 'Thinking about language', 'grade': '11', 'subject_code': 'english2', 'chapter_code': 'r5', 'subject_name': 'English', 'textbook_name': 'Hornbill', 'chapter_title': 'reading skills 5', 'section_title': 'Working with words', 'split_number': 9, 'total_splits': 12, 'source': '../extracted_text/english2_11_r5/english2_11_r5.md'}
# {'Header 1': '**Understanding Data**', 'grade': '11', 'subject_code': 'inf', 'chapter_code': '5', 'subject_name': 'Informatics Practices', 'textbook_name': 'Informatics Practices', 'chapter_title': 'chapter 5', 'section_title': '5.1 Introduction to Data', 'split_number': 2, 'total_splits': 31, 'source': '../extracted_text/inf_11_5/inf_11_5.md'}
# {'Header 1': 'Working of Institutions', 'grade': '9', 'subject_code': 'civics', 'chapter_code': '4', 'subject_name': 'Civics', 'textbook_name': 'Democractic Politics', 'chapter_title': 'chapter 4', 'section_title': 'OVERVIEW', 'split_number': 2, 'total_splits': 17, 'source': '../extracted_text/civics_9_4/civics_9_4.md'}
# {'Header 1': 'Working with words', 'Header 2': 'Understanding the text', 'Header 4': 'Thinking about language', 'grade': '11', 'subject_code': 'english2', 'chapter_code': 'r2', 'subject_name': 'English', 'textbook_name': 'Hornbill', 'chapter_title': 'reading skills 2', 'section_title': 'Things to do', 'split_number': 9, 'total_splits': 11, 'source': '../extracted_text/english2_11_r2/english2_11_r2.md'}
# {'Header 1': '**Migration**', 'grade': '12', 'subject_code': 'geo3', 'chapter_code': 'a1', 'subject_name': 'Geography', 'textbook_name': 'India-People and Economy', 'chapter_title': 'a1', 'section_title': 'Migration stream', 'split_number': 26, 'total_splits': 35, 'source': '../extracted_text/geo3_12_a1/geo3_12_a1.md'}
# {'Header 1': 'KEYWORDS ELECTRODE ELECTROPLATING GOOD CONDUCTOR LED POOR CONDUCTOR', 'Header 3': 'Extended Learning — Activities and Projects', 'Header 4': 'For more information on this topic visit:', 'grade': '8', 'subject_code': 'sci', 'chapter_code': '11', 'subject_name': 'Science', 'textbook_name': 'Science', 'chapter_title': 'chapter 11', 'section_title': 'For more information on this topic visit:', 'split_number': 16, 'total_splits': 17, 'source': '../extracted_text/sci_8_11/sci_8_11.md'}
# {'Header 1': '**GLOSSARY**', 'Header 3': '**Highway**', 'Header 4': '**Imports**', 'grade': '12', 'subject_code': 'geo', 'chapter_code': 'a1', 'subject_name': 'Geography', 'textbook_name': 'Fundamentals of Human Geography', 'chapter_title': 'appendix 1', 'section_title': 'Highway', 'split_number': 21, 'total_splits': 54, 'source': '../extracted_text/geo_12_a1/geo_12_a1.md'}
# {'Header 1': '**Encoding Schemes and Number System**', 'grade': '11', 'subject_code': 'comp', 'chapter_code': '2', 'subject_name': 'Computer Science', 'textbook_name': 'Computer Science', 'chapter_title': 'chapter 2', 'section_title': 'Encoding Schemes and \nNumber System', 'split_number': 2, 'total_splits': 41, 'source': '../extracted_text/comp_11_2/comp_11_2.md'}
# {'Header 1': '**THERMODYNAMICS**', 'grade': '11', 'subject_code': 'phy', 'chapter_code': '11', 'subject_name': 'Physics', 'textbook_name': 'Physics', 'chapter_title': 'chapter 11', 'section_title': 'THERMODYNAMICS', 'split_number': 2, 'total_splits': 31, 'source': '../extracted_text/phy_11_11/phy_11_11.md'}
# {'Header 2': 'ABOUT THE AUTHOR', 'Header 3': 'APPRECIATION', 'grade': '11', 'subject_code': 'english', 'chapter_code': 's2', 'subject_name': 'English', 'textbook_name': 'Woven Words', 'chapter_title': 'short stories 2', 'section_title': 'APPRECIATION', 'split_number': 5, 'total_splits': 9, 'source': '../extracted_text/english_11_s2/english_11_s2.md'}
# {'Header 1': 'The Institution of Marriage', 'grade': '11', 'subject_code': 'soc', 'chapter_code': '3', 'subject_name': 'Sociology', 'textbook_name': 'Introducing Sociology', 'chapter_title': 'chapter 3', 'section_title': 'Activity 2', 'split_number': 10, 'total_splits': 39, 'source': '../extracted_text/soc_11_3/soc_11_3.md'}
# {'Header 2': '**7.7 Definite Integral**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 27, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.7 Definite Integral**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 27, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 2': '**7.7 Definite Integral**', 'grade': '12', 'subject_code': 'math', 'chapter_code': '7', 'subject_name': 'Mathematics', 'textbook_name': 'Mathematics', 'chapter_title': 'chapter 7', 'section_title': 'Reprint 2024-25', 'split_number': 27, 'total_splits': 42, 'source': '../extracted_text/math_12_7/math_12_7.md'}
# {'Header 1': 'Human Memory Human MemoryHuman Memory', 'grade': '11', 'subject_code': 'psy', 'chapter_code': '6', 'subject_name': 'Psychology', 'textbook_name': 'Introduction to Psychology', 'chapter_title': 'chapter 6', 'section_title': 'Chapter6\nAfter reading this chapter, you would be able to', 'split_number': 2, 'total_splits': 36, 'source': '../extracted_text/psy_11_6/psy_11_6.md'}
# {'Header 1': '**Globalisation and Culture**', 'Header 4': 'Homogenisation Versus Glocalisation of Culture', 'grade': '12', 'subject_code': 'soc2', 'chapter_code': '6', 'subject_name': 'Sociology', 'textbook_name': 'Social Change and Development in India', 'chapter_title': 'chapter 6', 'section_title': 'Box 6.4', 'split_number': 24, 'total_splits': 32, 'source': '../extracted_text/soc2_12_6/soc2_12_6.md'}
# {'Header 2': '**Activity 10.3**', 'Header 4': '**10.4.1 Practising Waste Management and Segregation**', 'grade': '9', 'subject_code': 'pe', 'chapter_code': '10', 'subject_name': 'Health and Physical Education', 'textbook_name': 'Health and Physical Education', 'chapter_title': 'chapter 10', 'section_title': 'Activity 10.3', 'split_number': 13, 'total_splits': 19, 'source': '../extracted_text/pe_9_10/pe_9_10.md'}
# {'Header 1': '**Characteristics of**', 'grade': '12', 'subject_code': 'bus', 'chapter_code': '1', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 1', 'section_title': 'Characteristics of', 'split_number': 18, 'total_splits': 36, 'source': '../extracted_text/bus_12_1/bus_12_1.md'}
# {'Header 1': '**Global Communications**', 'Header 4': "**India's Telecommunications Expansion**", 'grade': '12', 'subject_code': 'soc2', 'chapter_code': '6', 'subject_name': 'Sociology', 'textbook_name': 'Social Change and Development in India', 'chapter_title': 'chapter 6', 'section_title': 'Activity 6.2', 'split_number': 16, 'total_splits': 32, 'source': '../extracted_text/soc2_12_6/soc2_12_6.md'}
# {'Header 1': '**Introduction to NumPy**', 'grade': '11', 'subject_code': 'inf', 'chapter_code': '6', 'subject_name': 'Informatics Practices', 'textbook_name': 'Informatics Practices', 'chapter_title': 'chapter 6', 'section_title': '6.1 Introduction', 'split_number': 2, 'total_splits': 48, 'source': '../extracted_text/inf_11_6/inf_11_6.md'}
# {'Header 1': '**Forms of Business Organisation**', 'grade': '11', 'subject_code': 'bus', 'chapter_code': '2', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 2', 'section_title': 'LEARNING OBJECTIVES', 'split_number': 2, 'total_splits': 52, 'source': '../extracted_text/bus_11_2/bus_11_2.md'}
# {'Header 1': '**International Business**', 'grade': '11', 'subject_code': 'bus', 'chapter_code': '11', 'subject_name': 'Business Studies', 'textbook_name': 'Business Studies', 'chapter_title': 'chapter 11', 'section_title': 'LEARNING OBJECTIVES', 'split_number': 2, 'total_splits': 51, 'source': '../extracted_text/bus_11_11/bus_11_11.md'}

# %% [markdown]
# # LLM

# %%
# !pip install 'accelerate>=0.26.0'
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting accelerate>=0.26.0
#   Downloading accelerate-1.4.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (24.2)
# Requirement already satisfied: psutil in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (7.0.0)
# Requirement already satisfied: pyyaml in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (0.29.3)
# Requirement already satisfied: safetensors>=0.4.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from accelerate>=0.26.0) (0.5.3)
# Requirement already satisfied: filelock in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (2025.3.0)
# Requirement already satisfied: requests in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.26.0) (4.12.2)
# Requirement already satisfied: networkx in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.4.2)
# Requirement already satisfied: jinja2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.2.0)
# Requirement already satisfied: setuptools in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (76.0.0)
# Requirement already satisfied: sympy==1.13.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate>=0.26.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->accelerate>=0.26.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/afoolishman/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate>=0.26.0) (2025.1.31)
# Downloading accelerate-1.4.0-py3-none-any.whl (342 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.4.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
model_version = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
tokenizer = AutoTokenizer.from_pretrained(model_version)
model = AutoModelForCausalLM.from_pretrained(model_version)
device = torch.device("cpu")
model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 5
#       3 model_version = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
#       4 tokenizer = AutoTokenizer.from_pretrained(model_version)
# ----> 5 model = AutoModelForCausalLM.from_pretrained(model_version, device_map="cpu")
#       6 device = torch.device("cpu")
#       7 model = model.to(device)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:262, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     260 old_dtype = torch.get_default_dtype()
#     261 try:
# --> 262     return func(*args, **kwargs)
#     263 finally:
#     264     torch.set_default_dtype(old_dtype)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/modeling_utils.py:3611, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3607         raise ValueError(
#    3608             "DeepSpeed Zero-3 is not compatible with `low_cpu_mem_usage=True` or with passing a `device_map`."
#    3609         )
#    3610     elif not is_accelerate_available():
# -> 3611         raise ImportError(
#    3612             f"Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#    3613         )
#    3615 # handling bnb config from kwargs, remove after `load_in_{4/8}bit` deprecation.
#    3616 if load_in_4bit or load_in_8bit:
#
# ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install 'accelerate>=0.26.0'`

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import pipeline
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
# Define the retriever
retriever = vector_store.as_retriever(search_kwargs={"k": 3})  # Retrieve top 3 chunks
# Create a Hugging Face pipeline for text generation
device = "cpu"
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    temperature=0.7,
    device=device
)
# Wrap the pipeline for LangChain compatibility
llm = HuggingFacePipeline(pipeline=pipe)
# Define the Prompt Template
template = """
Use the following context to answer the question. If unsure, say "I don't know."
Context:
{context}
Question: {question}
Answer:
"""
prompt = PromptTemplate(template=template, input_variables=["context", "question"])
# Define the RAG Chain
rag_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
# Out:
# Device set to use cpu

# %%
query = "What is differentiation?"
result = rag_chain({"query": query})
# Extract the generated answer
answer = result["result"].split("Answer:")[1].strip()
print(answer)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[30], line 2
#       1 query = "What is differentiation?"
# ----> 2 result = rag_chain({"query": query})
#       3 # Extract the generated answer
#       4 answer = result["result"].split("Answer:")[1].strip()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain/chains/base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)    380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain/chains/base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain/chains/retrieval_qa/base.py:151, in BaseRetrievalQA._call(self, inputs, run_manager)
#     147 accepts_run_manager = (
#     148     "run_manager" in inspect.signature(self._get_docs).parameters
#     149 )
#     150 if accepts_run_manager:
# --> 151     docs = self._get_docs(question, run_manager=_run_manager)
#     152 else:
#     153     docs = self._get_docs(question)  # type: ignore[call-arg]
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain/chains/retrieval_qa/base.py:271, in RetrievalQA._get_docs(self, question, run_manager)
#     264 def _get_docs(
#     265     self,
#     266     question: str,
#     267     *,
#     268     run_manager: CallbackManagerForChainRun,
#     269 ) -> List[Document]:
#     270     """Get docs."""
# --> 271     return self.retriever.invoke(
#     272         question, config={"callbacks": run_manager.get_child()}
#     273     )
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1074, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1072 _kwargs = self.search_kwargs | kwargs
#    1073 if self.search_type == "similarity":
# -> 1074     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1075 elif self.search_type == "similarity_score_threshold":
#    1076     docs_and_similarities = (
#    1077         self.vectorstore.similarity_search_with_relevance_scores(
#    1078             query, **_kwargs
#    1079         )
#    1080     )
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:643, in FAISS.similarity_search(self, query, k, filter, fetch_k, **kwargs)
#     623 def similarity_search(
#     624     self,
#     625     query: str,
#    (...)    629     **kwargs: Any,
#     630 ) -> List[Document]:
#     631     """Return docs most similar to query.
#     632
#     633     Args:
#    (...)    641         List of Documents most similar to the query.
#     642     """
# --> 643     docs_and_scores = self.similarity_search_with_score(
#     644         query, k, filter=filter, fetch_k=fetch_k, **kwargs
#     645     )
#     646     return [doc for doc, _ in docs_and_scores]
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:515, in FAISS.similarity_search_with_score(self, query, k, filter, fetch_k, **kwargs)
#     491 def similarity_search_with_score(
#     492     self,
#     493     query: str,
#    (...)    497     **kwargs: Any,
#     498 ) -> List[Tuple[Document, float]]:
#     499     """Return docs most similar to query.
#     500
#     501     Args:
#    (...)    513         L2 distance in float. Lower score represents more similarity.
#     514     """
# --> 515     embedding = self._embed_query(query)
#     516     docs = self.similarity_search_with_score_by_vector(
#     517         embedding,
#     518         k,
#    (...)    521         **kwargs,
#     522     )
#     523     return docs
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:266, in FAISS._embed_query(self, text)
#     264 def _embed_query(self, text: str) -> List[float]:
#     265     if isinstance(self.embedding_function, Embeddings):
# --> 266         return self.embedding_function.embed_query(text)
#     267     else:
#     268         return self.embedding_function(text)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_huggingface/embeddings/huggingface.py:108, in HuggingFaceEmbeddings.embed_query(self, text)
#      99 def embed_query(self, text: str) -> List[float]:
#     100     """Compute query embeddings using a HuggingFace transformer model.
#     101
#     102     Args:
#    (...)    106         Embeddings for the text.
#     107     """
# --> 108     return self.embed_documents([text])[0]
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/langchain_huggingface/embeddings/huggingface.py:85, in HuggingFaceEmbeddings.embed_documents(self, texts)
#      83     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#      84 else:
# ---> 85     embeddings = self._client.encode(
#      86         texts,
#      87         show_progress_bar=self.show_progress,
#      88         **self.encode_kwargs,  # type: ignore
#      89     )
#      91 if isinstance(embeddings, list):
#      92     raise TypeError(
#      93         "Expected embeddings to be a Tensor or a numpy array, "
#      94         "got a list instead."
#      95     )
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:623, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     620 features.update(extra_features)
#     622 with torch.no_grad():
# --> 623     out_features = self.forward(features, **kwargs)
#     624     if self.device.type == "hpu":
#     625         out_features = copy.deepcopy(out_features)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:690, in SentenceTransformer.forward(self, input, **kwargs)
#     688     module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     689     module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 690     input = module(input, **module_kwargs)
#     691 return input
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:442, in Transformer.forward(self, features, **kwargs)
#     435 """Returns token_embeddings, cls_token"""
#     436 trans_features = {
#     437     key: value
#     438     for key, value in features.items()
#     439     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     440 }
# --> 442 output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     443 output_tokens = output_states[0]
#     445 # If the AutoModel is wrapped with a PeftModelForFeatureExtraction, then it may have added virtual tokens
#     446 # We need to extend the attention mask to include these virtual tokens, or the pooling will fail
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:977, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     970 # Prepare head mask if needed
#     971 # 1.0 in head_mask indicate we keep the head
#     972 # attention_probs has shape bsz x n_heads x N x N
#     973 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     974 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     975 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 977 encoder_outputs = self.encoder(
#     978     embedding_output,
#     979     attention_mask=extended_attention_mask,
#     980     head_mask=head_mask,
#     981     encoder_hidden_states=encoder_hidden_states,
#     982     encoder_attention_mask=encoder_extended_attention_mask,
#     983     past_key_values=past_key_values,
#     984     use_cache=use_cache,
#     985     output_attentions=output_attentions,
#     986     output_hidden_states=output_hidden_states,
#     987     return_dict=return_dict,
#     988 )
#     989 sequence_output = encoder_outputs[0]
#     990 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:632, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     621     layer_outputs = self._gradient_checkpointing_func(
#     622         layer_module.__call__,
#     623         hidden_states,
#    (...)    629         output_attentions,
#     630     )
#     631 else:
# --> 632     layer_outputs = layer_module(
#     633         hidden_states,
#     634         attention_mask,
#     635         layer_head_mask,
#     636         encoder_hidden_states,
#     637         encoder_attention_mask,
#     638         past_key_value,
#     639         output_attentions,
#     640     )
#     642 hidden_states = layer_outputs[0]
#     643 if use_cache:
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:521, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     509 def forward(
#     510     self,
#     511     hidden_states: torch.Tensor,
#    (...)    518 ) -> Tuple[torch.Tensor]:
#     519     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     520     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 521     self_attention_outputs = self.attention(
#     522         hidden_states,
#     523         attention_mask,
#     524         head_mask,
#     525         output_attentions=output_attentions,
#     526         past_key_value=self_attn_past_key_value,
#     527     )
#     528     attention_output = self_attention_outputs[0]
#     530     # if decoder, the last output is tuple of self-attn cache
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:448, in XLMRobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     438 def forward(
#     439     self,
#     440     hidden_states: torch.Tensor,
#    (...)    446     output_attentions: Optional[bool] = False,
#     447 ) -> Tuple[torch.Tensor]:
# --> 448     self_outputs = self.self(
#     449         hidden_states,
#     450         attention_mask,
#     451         head_mask,
#     452         encoder_hidden_states,
#     453         encoder_attention_mask,
#     454         past_key_value,
#     455         output_attentions,
#     456     )
#     457     attention_output = self.output(self_outputs[0], hidden_states)
#     458     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:326, in XLMRobertaSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     314     return super().forward(
#     315         hidden_states,
#     316         attention_mask,
#    (...)    321         output_attentions,
#     322     )
#     324 bsz, tgt_len, _ = hidden_states.size()
# --> 326 query_layer = self.transpose_for_scores(self.query(hidden_states))
#     328 # If this is instantiated as a cross-attention module, the keys and values come from an encoder; the attention
#     329 # mask needs to be such that the encoder's padding tokens are not attended to.
#     330 is_cross_attention = encoder_hidden_states is not None
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/dass-spring-2025-project-team-47/.venv/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 5.79 GiB of which 5.69 MiB is free. Including non-PyTorch memory, this process has 5.77 GiB memory in use. Of the allocated memory 5.61 GiB is allocated by PyTorch, and 65.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

embeddings = HuggingFaceEmbeddings(model_name="Snowflake/snowflake-arctic-embed-l-v2.0")

index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(embedding_function=embeddings, index=index, docstore=InMemoryDocstore(), index_to_docstore_id={})
vector_store.load_local("faiss-index", embeddings=embeddings, allow_dangerous_deserialization=True)

retriever = vector_store.as_retriever(search_kwargs={"k": 3})  # Retrieve top 3 chunks

result = retriever.invoke("what is integration?")
print(result)

llm = HuggingFacePipeline.from_model_id(
    model_id="deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B",
    task="text-generation",
    device=-1,
    pipeline_kwargs=dict(
        max_new_tokens=256,
        temperature=0.7,
    )
)

chat_model = ChatHuggingFace(llm=llm)

RAG_TEMPLATE = """
You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.

<context>
{context}
</context>

Answer the following question:

{question}"""

rag_prompt = ChatPromptTemplate.from_template(RAG_TEMPLATE)


qa_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | rag_prompt
    | chat_model
    | StrOutputParser()
)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

embeddings = HuggingFaceEmbeddings(model_name="Snowflake/snowflake-arctic-embed-l-v2.0")

index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(embedding_function=embeddings, index=index, docstore=InMemoryDocstore(), index_to_docstore_id={})
vector_store.load_local("faiss-index", embeddings=embeddings, allow_dangerous_deserialization=True)

retriever = vector_store.as_retriever(search_kwargs={"k": 3})  # Retrieve top 3 chunks

result = retriever.invoke("what is integration?")
print(result)
