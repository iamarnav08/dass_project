# %%
# %pip install -U langchain-text-splitters langchain-community langgraph langchain-ollama langchain-chroma pandas markdown
# Out:
# Requirement already satisfied: langchain-text-splitters in ./.venv/lib/python3.12/site-packages (0.3.6)
# Requirement already satisfied: langchain-community in ./.venv/lib/python3.12/site-packages (0.3.19)
# Requirement already satisfied: langgraph in ./.venv/lib/python3.12/site-packages (0.3.7)
# Requirement already satisfied: langchain-ollama in ./.venv/lib/python3.12/site-packages (0.2.3)
# Requirement already satisfied: langchain-chroma in ./.venv/lib/python3.12/site-packages (0.2.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: markdown in ./.venv/lib/python3.12/site-packages (3.7)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in ./.venv/lib/python3.12/site-packages (from langchain-text-splitters) (0.3.43)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.12/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.12/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in ./.venv/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in ./.venv/lib/python3.12/site-packages (from langgraph) (2.0.18)
# Requirement already satisfied: langgraph-prebuilt<0.2,>=0.1.1 in ./.venv/lib/python3.12/site-packages (from langgraph) (0.1.2)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in ./.venv/lib/python3.12/site-packages (from langgraph) (0.1.55)
# Requirement already satisfied: ollama<1,>=0.4.4 in ./.venv/lib/python3.12/site-packages (from langchain-ollama) (0.4.7)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-chroma) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: build>=1.0.3 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.19.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.12/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-text-splitters) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-text-splitters) (24.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in ./.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: pyproject_hooks in ./.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.46.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.8.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: google-auth>=1.0.1 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: coloredlogs in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.29.3)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in ./.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.69.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.29.2)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2025.3.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Not needed until LLM is invoked
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = "YOUR_API_KEY"

# %%
from langchain_ollama import ChatOllama


llm = ChatOllama(
    model="llama3.1",
    temperature=0.7,
)

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
from langchain_chroma import Chroma

vector_store = Chroma(embedding_function=embeddings, persist_directory="./chroma_db-nomic")

# %% [markdown]
# ### Vectorizing Documents

# %%
# This is a small test
import os
import glob
import re
import json
from typing import List
import pandas as pd

from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain_core.documents import Document

def process_markdown_file(filepath: str, textbooks_df, special_chapters_df) -> List[Document]:

    # Get folder name from file path
    folder_name = os.path.basename(os.path.dirname(filepath))
    
    # Parse folder name to extract subject code, grade, and chapter code
    parts = folder_name.split('_')
    
    if len(parts) < 3:
        print(f"Warning: Folder name '{folder_name}' doesn't match expected format.")
        parsed_info = None
    
    subject_code = parts[0]
    grade = parts[1]
    chapter_code = '_'.join(parts[2:]) if len(parts) > 3 else parts[2]

    parsed_info = {
        "grade": grade,
        "subject_code": subject_code,
        "chapter_code": chapter_code
    }

    if not parsed_info:
        return []
    
    grade = parsed_info["grade"]
    subject_code = parsed_info["subject_code"]
    chapter_code = parsed_info["chapter_code"]
    
    # Look up subject name and textbook
    subject_info = textbooks_df[
        (textbooks_df['grade'] == int(grade)) & 
        (textbooks_df['subjectcode'] == subject_code)
    ]
    
    if subject_info.empty:
        print(f"Warning: No subject info found for grade {grade}, subject code {subject_code}")
        subject_name = subject_code
        textbook_name = "Unknown"
    else:
        subject_name = subject_info['subjectname'].iloc[0]
        textbook_name = subject_info['textbook'].iloc[0]
    
    # Format chapter title
    # Check if this is a special chapter
    chapter_title = chapter_code
    
    match = re.match(r'([a-zA-Z]+)(\d+)', chapter_code)
    if match:
        letter_code = match.group(1)
        number = match.group(2)
        
        # Look up special chapter in dataframe
        special_chapter = special_chapters_df[
            (special_chapters_df['grade'] == int(grade)) & 
            (special_chapters_df['subjectcode'] == subject_code) & 
            (special_chapters_df['special_chaptercode'] == letter_code)
        ]
        
        if not special_chapter.empty:
            chapter_type = special_chapter['chaptertype'].iloc[0]
            chapter_title = f"{chapter_type} {number}"
    
    # If it's just a number or didn't match any special chapter
    if chapter_code.isdigit():
        chapter_title = f"chapter {chapter_code}"
    
    # Load the markdown file
    loader = TextLoader(filepath)
    documents = loader.load()

    meta_filepath = os.path.join(os.path.dirname(filepath), os.path.basename(filepath).replace('.md', '_meta.json'))
    section_titles = []

    if os.path.exists(meta_filepath):
        with open(meta_filepath, 'r') as f:
            metadata = json.load(f)

            for section in metadata.get('table_of_contents', []):
                title = section.get('title', '')
                section_titles.append(title)

    headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3"), ("####", "Header 4")]

    text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on, strip_headers=False)
    chunks = text_splitter.split_text(documents[0].page_content)
    print(len(chunks), len(section_titles))
    
    # Add metadata to each chunk
    for i, chunk in enumerate(chunks):
        section_title = section_titles[i] if i < len(section_titles) else ""

        chunk.metadata.update({
            "grade": grade,
            "subject_code": subject_code,
            "chapter_code": chapter_code,
            "subject_name": subject_name,
            "textbook_name": textbook_name,
            "chapter_title": chapter_title,
            "section_title": section_title,
            "split_number": i + 1,
            "total_splits": len(chunks),
            "source": filepath
        })
    
    if len(chunks) != len(section_titles):
        print(f"Warning: Number of chunks ({len(chunks)}) doesn't match number of section titles ({len(section_titles)}) for {filepath}")

    return chunks

textbooks_df = pd.read_csv("textbooks.csv")
special_chapters_df = pd.read_csv("special_chapters.csv")

markdown_files = glob.glob(os.path.join("../marker-output", "**/*.md"), recursive=True)
print(f"Found {len(markdown_files)} markdown files to process")

for file_path in markdown_files:
        print(f"Processing file: {file_path}")
        try:
            chunks = process_markdown_file(file_path, textbooks_df, special_chapters_df)
            vector_store.add_documents(chunks)
            print(f"Successfully processed {file_path}")
        except Exception as e:
            print(f"Error processing {file_path}: {str(e)}")
    
print("Finished processing all markdown files")
# Out:
# Found 783 markdown files to process
# Processing file: ../marker-output/soc2_11_1/soc2_11_1.md
# 24 24
# Successfully processed ../marker-output/soc2_11_1/soc2_11_1.md
# Processing file: ../marker-output/bio_11_3/bio_11_3.md
# 16 18
# Warning: Number of chunks (16) doesn't match number of section titles (18) for ../marker-output/bio_11_3/bio_11_3.md
# Successfully processed ../marker-output/bio_11_3/bio_11_3.md
# Processing file: ../marker-output/english_11_s8/english_11_s8.md
# 7 6
# Warning: Number of chunks (7) doesn't match number of section titles (6) for ../marker-output/english_11_s8/english_11_s8.md
# Successfully processed ../marker-output/english_11_s8/english_11_s8.md
# Processing file: ../marker-output/bus_11_3/bus_11_3.md
# 37 39
# Warning: Number of chunks (37) doesn't match number of section titles (39) for ../marker-output/bus_11_3/bus_11_3.md
# Successfully processed ../marker-output/bus_11_3/bus_11_3.md
# Processing file: ../marker-output/eco_10_4/eco_10_4.md
# 38 40
# Processing file: ../marker-output/psy_12_1/psy_12_1.md
# 42 44
# Warning: Number of chunks (42) doesn't match number of section titles (44) for ../marker-output/psy_12_1/psy_12_1.md
# Successfully processed ../marker-output/psy_12_1/psy_12_1.md
# Processing file: ../marker-output/history_10_1/history_10_1.md
# 54 62
# Warning: Number of chunks (54) doesn't match number of section titles (62) for ../marker-output/history_10_1/history_10_1.md
# Successfully processed ../marker-output/history_10_1/history_10_1.md
# Processing file: ../marker-output/bio_11_10/bio_11_10.md
# 17 16
# Warning: Number of chunks (17) doesn't match number of section titles (16) for ../marker-output/bio_11_10/bio_11_10.md
# Successfully processed ../marker-output/bio_11_10/bio_11_10.md
# Processing file: ../marker-output/pol_11_2/pol_11_2.md
# 19 28
# Warning: Number of chunks (19) doesn't match number of section titles (28) for ../marker-output/pol_11_2/pol_11_2.md
# Successfully processed ../marker-output/pol_11_2/pol_11_2.md
# Processing file: ../marker-output/geo_11_12/geo_11_12.md
# 24 26
# Warning: Number of chunks (24) doesn't match number of section titles (26) for ../marker-output/geo_11_12/geo_11_12.md
# Successfully processed ../marker-output/geo_11_12/geo_11_12.md
# Processing file: ../marker-output/home_12_10/home_12_10.md
# 18 18
# Successfully processed ../marker-output/home_12_10/home_12_10.md
# Processing file: ../marker-output/home_12_2/home_12_2.md
# 18 18
# Successfully processed ../marker-output/home_12_2/home_12_2.md
# Processing file: ../marker-output/kno_11_6/kno_11_6.md
# 28 29
# Warning: Number of chunks (28) doesn't match number of section titles (29) for ../marker-output/kno_11_6/kno_11_6.md
# Successfully processed ../marker-output/kno_11_6/kno_11_6.md
# Processing file: ../marker-output/home_12_8/home_12_8.md
# 28 29
# Warning: Number of chunks (28) doesn't match number of section titles (29) for ../marker-output/home_12_8/home_12_8.md
# Successfully processed ../marker-output/home_12_8/home_12_8.md
# Processing file: ../marker-output/math_8_13/math_8_13.md
# 20 20
# Successfully processed ../marker-output/math_8_13/math_8_13.md
# Processing file: ../marker-output/bus_12_5/bus_12_5.md
# 42 46
# Warning: Number of chunks (42) doesn't match number of section titles (46) for ../marker-output/bus_12_5/bus_12_5.md
# Successfully processed ../marker-output/bus_12_5/bus_12_5.md
# Processing file: ../marker-output/bio_11_14/bio_11_14.md
# 15 15
# Successfully processed ../marker-output/bio_11_14/bio_11_14.md
# Processing file: ../marker-output/history_12_2/history_12_2.md
# 56 68
# Warning: Number of chunks (56) doesn't match number of section titles (68) for ../marker-output/history_12_2/history_12_2.md
# Successfully processed ../marker-output/history_12_2/history_12_2.md
# Processing file: ../marker-output/sci_10_4/sci_10_4.md
# 50 56
# Warning: Number of chunks (50) doesn't match number of section titles (56) for ../marker-output/sci_10_4/sci_10_4.md
# Successfully processed ../marker-output/sci_10_4/sci_10_4.md
# Processing file: ../marker-output/english2_9_3/english2_9_3.md
# 3 2
# Warning: Number of chunks (3) doesn't match number of section titles (2) for ../marker-output/english2_9_3/english2_9_3.md
# Successfully processed ../marker-output/english2_9_3/english2_9_3.md
# Processing file: ../marker-output/chem_11_7/chem_11_7.md
# Warning: Number of chunks (23) doesn't match number of section titles (24) for ../marker-output/pol2_11_9/pol2_11_9.md
# Successfully processed ../marker-output/pol2_11_9/pol2_11_9.md
# Processing file: ../marker-output/eco2_12_4/eco2_12_4.md
# 22 21
# Warning: Number of chunks (22) doesn't match number of section titles (21) for ../marker-output/eco2_12_4/eco2_12_4.md
# Successfully processed ../marker-output/eco2_12_4/eco2_12_4.md
# Processing file: ../marker-output/english_10_1/english_10_1.md
# 17 23
# Warning: Number of chunks (17) doesn't match number of section titles (23) for ../marker-output/english_10_1/english_10_1.md
# Successfully processed ../marker-output/english_10_1/english_10_1.md
# Processing file: ../marker-output/geo3_12_6/geo3_12_6.md
# 11 10
# Warning: Number of chunks (11) doesn't match number of section titles (10) for ../marker-output/geo3_12_6/geo3_12_6.md
# Successfully processed ../marker-output/geo3_12_6/geo3_12_6.md
# ...
# Processing file: ../marker-output/biotech_11_4/biotech_11_4.md
# 31 31
# Successfully processed ../marker-output/biotech_11_4/biotech_11_4.md
# Processing file: ../marker-output/comp_11_7/comp_11_7.md
# 51 53
# Warning: Number of chunks (51) doesn't match number of section titles (53) for ../marker-output/comp_11_7/comp_11_7.md
# Successfully processed ../marker-output/comp_11_7/comp_11_7.md
# Processing file: ../marker-output/bio_12_10/bio_12_10.md
# 12 14
# Warning: Number of chunks (12) doesn't match number of section titles (14) for ../marker-output/bio_12_10/bio_12_10.md
# Successfully processed ../marker-output/bio_12_10/bio_12_10.md
# Processing file: ../marker-output/english3_10_5/english3_10_5.md
# 22 24
# Warning: Number of chunks (22) doesn't match number of section titles (24) for ../marker-output/english3_10_5/english3_10_5.md
# Successfully processed ../marker-output/english3_10_5/english3_10_5.md
# Processing file: ../marker-output/phy_11_5/phy_11_5.md
# 24 23
# Warning: Number of chunks (24) doesn't match number of section titles (23) for ../marker-output/phy_11_5/phy_11_5.md
# Successfully processed ../marker-output/phy_11_5/phy_11_5.md
# Processing file: ../marker-output/soc_11_3/soc_11_3.md
# 39 40
# Warning: Number of chunks (39) doesn't match number of section titles (40) for ../marker-output/soc_11_3/soc_11_3.md
# Successfully processed ../marker-output/soc_11_3/soc_11_3.md
# Processing file: ../marker-output/sci_10_1/sci_10_1.md
# 31 32
# Warning: Number of chunks (31) doesn't match number of section titles (32) for ../marker-output/sci_10_1/sci_10_1.md
# Successfully processed ../marker-output/sci_10_1/sci_10_1.md
# Processing file: ../marker-output/phy_12_8/phy_12_8.md
# 20 27
# Warning: Number of chunks (20) doesn't match number of section titles (27) for ../marker-output/phy_12_8/phy_12_8.md
# Successfully processed ../marker-output/phy_12_8/phy_12_8.md
# Processing file: ../marker-output/math_10_6/math_10_6.md
# 10 12
# Warning: Number of chunks (10) doesn't match number of section titles (12) for ../marker-output/math_10_6/math_10_6.md
# Successfully processed ../marker-output/math_10_6/math_10_6.md
# Processing file: ../marker-output/english2_9_5/english2_9_5.md
# 3 2
# Warning: Number of chunks (3) doesn't match number of section titles (2) for ../marker-output/english2_9_5/english2_9_5.md
# Successfully processed ../marker-output/english2_9_5/english2_9_5.md
# Processing file: ../marker-output/civics_10_1/civics_10_1.md
# 7 7
# Successfully processed ../marker-output/civics_10_1/civics_10_1.md
# Processing file: ../marker-output/home_12_7/home_12_7.md
# 48 56
# Warning: Number of chunks (48) doesn't match number of section titles (56) for ../marker-output/home_12_7/home_12_7.md
# Successfully processed ../marker-output/home_12_7/home_12_7.md
# Processing file: ../marker-output/comp_11_11/comp_11_11.md
# 51 53
# Warning: Number of chunks (51) doesn't match number of section titles (53) for ../marker-output/comp_11_11/comp_11_11.md
# Successfully processed ../marker-output/comp_11_11/comp_11_11.md
# Processing file: ../marker-output/chem_12_3/chem_12_3.md
# 17 16
# Warning: Number of chunks (17) doesn't match number of section titles (16) for ../marker-output/chem_12_3/chem_12_3.md
# Successfully processed ../marker-output/chem_12_3/chem_12_3.md
# Processing file: ../marker-output/english_11_e2/english_11_e2.md
# 4 3
# Warning: Number of chunks (4) doesn't match number of section titles (3) for ../marker-output/english_11_e2/english_11_e2.md
# Successfully processed ../marker-output/english_11_e2/english_11_e2.md
# Processing file: ../marker-output/biotech_11_12/biotech_11_12.md
# 51 52
# Warning: Number of chunks (51) doesn't match number of section titles (52) for ../marker-output/biotech_11_12/biotech_11_12.md
# Successfully processed ../marker-output/biotech_11_12/biotech_11_12.md
# Processing file: ../marker-output/english3_10_2/english3_10_2.md
# 16 18
# Warning: Number of chunks (16) doesn't match number of section titles (18) for ../marker-output/english3_10_2/english3_10_2.md
# Successfully processed ../marker-output/english3_10_2/english3_10_2.md
# Processing file: ../marker-output/math_10_8/math_10_8.md
# 12 13
# Warning: Number of chunks (12) doesn't match number of section titles (13) for ../marker-output/math_10_8/math_10_8.md
# Successfully processed ../marker-output/math_10_8/math_10_8.md
# Processing file: ../marker-output/pe_9_9/pe_9_9.md
# 118 120
# Warning: Number of chunks (118) doesn't match number of section titles (120) for ../marker-output/pe_9_9/pe_9_9.md
# Successfully processed ../marker-output/pe_9_9/pe_9_9.md
# Processing file: ../marker-output/art_12_8/art_12_8.md
# 11 11
# Successfully processed ../marker-output/art_12_8/art_12_8.md
# Processing file: ../marker-output/kno_11_3/kno_11_3.md
# 48 48
# Successfully processed ../marker-output/kno_11_3/kno_11_3.md
# Processing file: ../marker-output/english3_10_3/english3_10_3.md
# 22 24
# Warning: Number of chunks (22) doesn't match number of section titles (24) for ../marker-output/english3_10_3/english3_10_3.md
# Successfully processed ../marker-output/english3_10_3/english3_10_3.md
# Processing file: ../marker-output/pe_9_2/pe_9_2.md
# 43 52
# Warning: Number of chunks (43) doesn't match number of section titles (52) for ../marker-output/pe_9_2/pe_9_2.md
# Successfully processed ../marker-output/pe_9_2/pe_9_2.md
# Processing file: ../marker-output/bus_12_11/bus_12_11.md
# 27 26
# Warning: Number of chunks (27) doesn't match number of section titles (26) for ../marker-output/bus_12_11/bus_12_11.md
# Successfully processed ../marker-output/bus_12_11/bus_12_11.md
# Processing file: ../marker-output/phy_12_1/phy_12_1.md
# 36 57
# Warning: Number of chunks (36) doesn't match number of section titles (57) for ../marker-output/phy_12_1/phy_12_1.md
# Successfully processed ../marker-output/phy_12_1/phy_12_1.md
# Processing file: ../marker-output/geo_8_2/geo_8_2.md
# 34 34
# Successfully processed ../marker-output/geo_8_2/geo_8_2.md
# Processing file: ../marker-output/math_8_2/math_8_2.md
# 6 7
# Warning: Number of chunks (6) doesn't match number of section titles (7) for ../marker-output/math_8_2/math_8_2.md
# Successfully processed ../marker-output/math_8_2/math_8_2.md
# Processing file: ../marker-output/bus_12_8/bus_12_8.md
# 17 19
# Warning: Number of chunks (17) doesn't match number of section titles (19) for ../marker-output/bus_12_8/bus_12_8.md
# Successfully processed ../marker-output/bus_12_8/bus_12_8.md
# Processing file: ../marker-output/english2_8_4/english2_8_4.md
# 10 11
# Warning: Number of chunks (10) doesn't match number of section titles (11) for ../marker-output/english2_8_4/english2_8_4.md
# Successfully processed ../marker-output/english2_8_4/english2_8_4.md
# Processing file: ../marker-output/pe_10_4/pe_10_4.md
# 33 38
# Warning: Number of chunks (33) doesn't match number of section titles (38) for ../marker-output/pe_10_4/pe_10_4.md
# Successfully processed ../marker-output/pe_10_4/pe_10_4.md
# Processing file: ../marker-output/chem_12_a1/chem_12_a1.md
# 23 27
# Warning: Number of chunks (23) doesn't match number of section titles (27) for ../marker-output/chem_12_a1/chem_12_a1.md
# Successfully processed ../marker-output/chem_12_a1/chem_12_a1.md
# Processing file: ../marker-output/eco2_11_7/eco2_11_7.md
# 32 33
# Warning: Number of chunks (32) doesn't match number of section titles (33) for ../marker-output/eco2_11_7/eco2_11_7.md
# Successfully processed ../marker-output/eco2_11_7/eco2_11_7.md
# Processing file: ../marker-output/math_12_a1/math_12_a1.md
# 7 9
# Warning: Number of chunks (7) doesn't match number of section titles (9) for ../marker-output/math_12_a1/math_12_a1.md
# Successfully processed ../marker-output/math_12_a1/math_12_a1.md
# Processing file: ../marker-output/psy_12_6/psy_12_6.md
# 26 26
# Successfully processed ../marker-output/psy_12_6/psy_12_6.md
# Processing file: ../marker-output/phy_11_a1/phy_11_a1.md
# 29 38
# Warning: Number of chunks (29) doesn't match number of section titles (38) for ../marker-output/phy_11_a1/phy_11_a1.md
# Successfully processed ../marker-output/phy_11_a1/phy_11_a1.md
# Processing file: ../marker-output/acc_12_2/acc_12_2.md
# 123 133
# Warning: Number of chunks (123) doesn't match number of section titles (133) for ../marker-output/acc_12_2/acc_12_2.md
# Successfully processed ../marker-output/acc_12_2/acc_12_2.md
# Processing file: ../marker-output/bus_12_3/bus_12_3.md
# 26 27
# Warning: Number of chunks (26) doesn't match number of section titles (27) for ../marker-output/bus_12_3/bus_12_3.md
# Successfully processed ../marker-output/bus_12_3/bus_12_3.md
# Processing file: ../marker-output/soc2_11_2/soc2_11_2.md
# 26 26
# Successfully processed ../marker-output/soc2_11_2/soc2_11_2.md
# Processing file: ../marker-output/math_11_6/math_11_6.md
# 14 20
# Warning: Number of chunks (14) doesn't match number of section titles (20) for ../marker-output/math_11_6/math_11_6.md
# Successfully processed ../marker-output/math_11_6/math_11_6.md
# Processing file: ../marker-output/pol_11_8/pol_11_8.md
# 26 40
# Warning: Number of chunks (26) doesn't match number of section titles (40) for ../marker-output/pol_11_8/pol_11_8.md
# Successfully processed ../marker-output/pol_11_8/pol_11_8.md
# Processing file: ../marker-output/comp_12_7/comp_12_7.md
# 33 38
# Warning: Number of chunks (33) doesn't match number of section titles (38) for ../marker-output/comp_12_7/comp_12_7.md
# Successfully processed ../marker-output/comp_12_7/comp_12_7.md
# Processing file: ../marker-output/pol_12_1/pol_12_1.md
# 20 28
# Warning: Number of chunks (20) doesn't match number of section titles (28) for ../marker-output/pol_12_1/pol_12_1.md
# Successfully processed ../marker-output/pol_12_1/pol_12_1.md
# Processing file: ../marker-output/pe_11_7/pe_11_7.md
# 60 65
# Warning: Number of chunks (60) doesn't match number of section titles (65) for ../marker-output/pe_11_7/pe_11_7.md
# Successfully processed ../marker-output/pe_11_7/pe_11_7.md
# Processing file: ../marker-output/ict_9_5/ict_9_5.md
# 4 3
# Warning: Number of chunks (4) doesn't match number of section titles (3) for ../marker-output/ict_9_5/ict_9_5.md
# Successfully processed ../marker-output/ict_9_5/ict_9_5.md
# Processing file: ../marker-output/bus_12_10/bus_12_10.md
# 65 64
# Warning: Number of chunks (65) doesn't match number of section titles (64) for ../marker-output/bus_12_10/bus_12_10.md
# Successfully processed ../marker-output/bus_12_10/bus_12_10.md
# Processing file: ../marker-output/history_12_11/history_12_11.md
# 57 71
# Warning: Number of chunks (57) doesn't match number of section titles (71) for ../marker-output/history_12_11/history_12_11.md
# Successfully processed ../marker-output/history_12_11/history_12_11.md
# Processing file: ../marker-output/english_9_5/english_9_5.md
# 14 14
# Successfully processed ../marker-output/english_9_5/english_9_5.md
# Processing file: ../marker-output/sci_9_8/sci_9_8.md
# 19 21
# Warning: Number of chunks (19) doesn't match number of section titles (21) for ../marker-output/sci_9_8/sci_9_8.md
# Successfully processed ../marker-output/sci_9_8/sci_9_8.md
# Processing file: ../marker-output/eco2_11_5/eco2_11_5.md
# 51 51
# Successfully processed ../marker-output/eco2_11_5/eco2_11_5.md
# Processing file: ../marker-output/english2_11_r4/english2_11_r4.md
# 9 8
# Warning: Number of chunks (9) doesn't match number of section titles (8) for ../marker-output/english2_11_r4/english2_11_r4.md
# Successfully processed ../marker-output/english2_11_r4/english2_11_r4.md
# Processing file: ../marker-output/history_11_5/history_11_5.md
# 22 28
# Warning: Number of chunks (22) doesn't match number of section titles (28) for ../marker-output/history_11_5/history_11_5.md
# Successfully processed ../marker-output/history_11_5/history_11_5.md
# Processing file: ../marker-output/english_11_p11/english_11_p11.md
# 6 5
# Warning: Number of chunks (6) doesn't match number of section titles (5) for ../marker-output/english_11_p11/english_11_p11.md
# Successfully processed ../marker-output/english_11_p11/english_11_p11.md
# Processing file: ../marker-output/biotech_11_9/biotech_11_9.md
# 33 34
# Warning: Number of chunks (33) doesn't match number of section titles (34) for ../marker-output/biotech_11_9/biotech_11_9.md
# Successfully processed ../marker-output/biotech_11_9/biotech_11_9.md
# Processing file: ../marker-output/soc_12_1/soc_12_1.md
# 3 3
# Successfully processed ../marker-output/soc_12_1/soc_12_1.md
# Processing file: ../marker-output/geo_10_2/geo_10_2.md
# 8 12
# Warning: Number of chunks (8) doesn't match number of section titles (12) for ../marker-output/geo_10_2/geo_10_2.md
# Successfully processed ../marker-output/geo_10_2/geo_10_2.md
# Processing file: ../marker-output/history_8_5/history_8_5.md
# 22 22
# Successfully processed ../marker-output/history_8_5/history_8_5.md
# Processing file: ../marker-output/civics_8_6/civics_8_6.md
# 11 10
# Warning: Number of chunks (11) doesn't match number of section titles (10) for ../marker-output/civics_8_6/civics_8_6.md
# Successfully processed ../marker-output/civics_8_6/civics_8_6.md
# Processing file: ../marker-output/geo_11_1/geo_11_1.md
# 15 16
# Warning: Number of chunks (15) doesn't match number of section titles (16) for ../marker-output/geo_11_1/geo_11_1.md
# Successfully processed ../marker-output/geo_11_1/geo_11_1.md
# Processing file: ../marker-output/english2_12_po2/english2_12_po2.md
# 5 4
# Warning: Number of chunks (5) doesn't match number of section titles (4) for ../marker-output/english2_12_po2/english2_12_po2.md
# Successfully processed ../marker-output/english2_12_po2/english2_12_po2.md
# Processing file: ../marker-output/pol2_11_8/pol2_11_8.md
# 22 27
# Warning: Number of chunks (22) doesn't match number of section titles (27) for ../marker-output/pol2_11_8/pol2_11_8.md
# Successfully processed ../marker-output/pol2_11_8/pol2_11_8.md
# Processing file: ../marker-output/bio_11_17/bio_11_17.md
# 13 14
# Warning: Number of chunks (13) doesn't match number of section titles (14) for ../marker-output/bio_11_17/bio_11_17.md
# Successfully processed ../marker-output/bio_11_17/bio_11_17.md
# Processing file: ../marker-output/inf_11_5/inf_11_5.md
# 31 31
# Successfully processed ../marker-output/inf_11_5/inf_11_5.md
# Processing file: ../marker-output/pol_11_3/pol_11_3.md
# 25 28
# Warning: Number of chunks (25) doesn't match number of section titles (28) for ../marker-output/pol_11_3/pol_11_3.md
# Successfully processed ../marker-output/pol_11_3/pol_11_3.md
# Processing file: ../marker-output/geo_12_a1/geo_12_a1.md
# 54 56
# Warning: Number of chunks (54) doesn't match number of section titles (56) for ../marker-output/geo_12_a1/geo_12_a1.md
# Successfully processed ../marker-output/geo_12_a1/geo_12_a1.md
# Processing file: ../marker-output/soc_11_1/soc_11_1.md
# 36 39
# Warning: Number of chunks (36) doesn't match number of section titles (39) for ../marker-output/soc_11_1/soc_11_1.md
# Successfully processed ../marker-output/soc_11_1/soc_11_1.md
# Processing file: ../marker-output/chem_11_a1/chem_11_a1.md
# 19 23
# Warning: Number of chunks (19) doesn't match number of section titles (23) for ../marker-output/chem_11_a1/chem_11_a1.md
# Successfully processed ../marker-output/chem_11_a1/chem_11_a1.md
# Processing file: ../marker-output/pe_9_7/pe_9_7.md
# 68 76
# Warning: Number of chunks (68) doesn't match number of section titles (76) for ../marker-output/pe_9_7/pe_9_7.md
# Successfully processed ../marker-output/pe_9_7/pe_9_7.md
# Processing file: ../marker-output/sci_10_2/sci_10_2.md
# 57 61
# Warning: Number of chunks (57) doesn't match number of section titles (61) for ../marker-output/sci_10_2/sci_10_2.md
# Successfully processed ../marker-output/sci_10_2/sci_10_2.md
# Processing file: ../marker-output/phy_11_1/phy_11_1.md
# 22 21
# Warning: Number of chunks (22) doesn't match number of section titles (21) for ../marker-output/phy_11_1/phy_11_1.md
# Successfully processed ../marker-output/phy_11_1/phy_11_1.md
# Processing file: ../marker-output/geo_11_9/geo_11_9.md
# 27 27
# Successfully processed ../marker-output/geo_11_9/geo_11_9.md
# Processing file: ../marker-output/home_11_7/home_11_7.md
# 69 78
# Warning: Number of chunks (69) doesn't match number of section titles (78) for ../marker-output/home_11_7/home_11_7.md
# Successfully processed ../marker-output/home_11_7/home_11_7.md
# Finished processing all markdown files

# %% [markdown]
# ### Process Query

# %% [markdown]
# #### Custom Retriever Class

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.retrievers import BaseRetriever
from typing import List, Dict, Any, Optional
from langchain_core.documents import Document
from pydantic import Field

# Define your custom retriever
class ContextExpandedFilteredRetriever(BaseRetriever):
    """Retriever that fetches top result plus surrounding context chunks with filtering."""
    
    # Explicitly define fields using Pydantic Field
    vectorstore: Any = Field(description="Vector store for retrievals")
    grade: str = Field(description="Grade level for filtering")
    subjects: List[str] = Field(description="List of subject codes for filtering")
    context_window: int = Field(default=5, description="Number of context chunks to retrieve")
    
    def _get_relevant_documents(self, query: str) -> List[Document]:
        # Create a filter for grade and subjects
        filter_dict = {
            "$and": [
                {"grade": self.grade},
                {"subject_code": {"$in": self.subjects}}
            ]
        }
        
        # Get the top result with filters
        results = self.vectorstore.similarity_search(
            query, 
            k=1,
            filter=filter_dict
        )
        if not results:
            return []
            
        top_result = results[0]
        
        # Extract metadata to identify position
        split_number = top_result.metadata.get("split_number", 0)
        total_splits = top_result.metadata.get("total_splits", 0)
        chapter_code = top_result.metadata.get("chapter_code")
        subject_code = top_result.metadata.get("subject_code")
        
        # Calculate range of splits to retrieve
        start_split = max(1, split_number - self.context_window)
        end_split = min(total_splits, split_number + self.context_window)
        
        # Retrieve all the relevant splits
        expanded_results = [top_result]  # Start with the top result
        
        # Get context before the top result
        for i in range(start_split, split_number):
            # Create a filter for this specific split
            split_filter = {
                "$and": [
                    {"grade": self.grade},
                    {"subject_code": subject_code},
                    {"chapter_code": chapter_code},
                    {"split_number": i}
                ]
            }
            
            context_docs = self.vectorstore.similarity_search(
                "", # Empty query to avoid biasing results
                k=1,
                filter=split_filter
            )
            
            if context_docs:
                expanded_results.insert(0, context_docs[0])  # Add before top result
        
        # Get context after the top result
        for i in range(split_number + 1, end_split + 1):
            # Create a filter for this specific split
            split_filter = {
                "$and": [
                    {"grade": self.grade},
                    {"subject_code": subject_code},
                    {"chapter_code": chapter_code},
                    {"split_number": i}
                ]
            }
            
            context_docs = self.vectorstore.similarity_search(
                "", # Empty query to avoid biasing results
                k=1,
                filter=split_filter
            )
            
            if context_docs:
                expanded_results.append(context_docs[0])  # Add after top result
        
        return expanded_results

# %% [markdown]
# #### Stream Generator Function

# %%
def generate(template, grade, subjects, query):
    # Create the custom retriever
    
    retriever = ContextExpandedFilteredRetriever(
        vectorstore=vector_store,  # Your vector store instance
        grade=grade,
        subjects=subjects,
        context_window=5  # Retrieve 5 chunks before and after
    )

    # Create the prompt template
    prompt = ChatPromptTemplate.from_template(template)

    # Build the chain
    chain = (
        {"context": retriever, "question": RunnablePassthrough()}
        | prompt
        | llm
        | StrOutputParser()
    )

    # Run the chain
    for chunk in chain.stream(query):
        yield chunk

# %% [markdown]
# #### Testcases

# %% [markdown]
# Prompt Template

# %%
template = """Answer the question based only on the following context:
{context}
Question: {question}
"""

# %%
grade = "11"
subjects = ["bio", "chem", "phy", "math"]
query = "What is differentiation"

for chunk in generate(template, grade, subjects, query):
    print(chunk, end="", flush=True)
# Out:
# Differentiation refers to the process of cells becoming specialized in structure and function to perform specific tasks within an organism. In the context of plant growth, differentiation involves the transformation of undifferentiated cells into specialized cells with distinct characteristics, such as root cells, leaf cells, or vascular tissue cells.
#
# In the provided text, it is mentioned that "Auxins like IAA and indole butyric acid (IBA) have been isolated from plants. NAA (naphthalene acetic acid) and 2, 4-D (2, 4-dichlorophenoxyacetic) are synthetic auxins." This implies that auxins play a role in promoting differentiation in plant cells.
#
# However, the text does not explicitly define differentiation.

# %%
grade = "11"
subjects = ["chem", "phy", "math", "comp"]
query = "What is differentiation"

for chunk in generate(template, grade, subjects, query):
    print(chunk, end="", flush=True)
# Out:
# Differentiation is a fundamental concept in calculus that deals with the study of rates of change and slopes of curves. It is a mathematical operation that finds the derivative of a function, which represents the rate at which the function changes as its input (or independent variable) changes.
#
# In other words, differentiation measures how fast a function changes when its input changes. It is used to find the slope of a curve at a given point, and it can be thought of as the limit of the ratio of the change in the output of a function to the change in its input as the input changes.
#
# There are several types of differentiation, including:
#
# 1. **First derivative**: This measures the rate of change of a function with respect to its input.
# 2. **Second derivative**: This measures the rate of change of the first derivative with respect to the input.
# 3. **Higher-order derivatives**: These measure the rate of change of higher-order derivatives with respect to the input.
#
# Differentiation has numerous applications in various fields, including:
#
# 1. **Physics and engineering**: Differentiation is used to describe the motion of objects, forces, and energies.
# 2. **Economics**: Differentiation is used to model economic systems, understand consumer behavior, and analyze market trends.
# 3. **Biology**: Differentiation is used to study population growth, disease spread, and genetic variation.
# 4. **Computer science**: Differentiation is used in machine learning, optimization algorithms, and data analysis.
#
# Some common differentiation rules include:
#
# 1. **Power rule**: If f(x) = x^n, then f'(x) = nx^(n-1)
# 2. **Product rule**: If f(x) = u(x)v(x), then f'(x) = u'(x)v(x) + u(x)v'(x)
# 3. **Quotient rule**: If f(x) = u(x)/v(x), then f'(x) = (u'(x)v(x) - u(x)v'(x)) / v(x)^2
# 4. **Chain rule**: If f(x) = g(h(x)), then f'(x) = g'(h(x)) \* h'(x)
#
# These rules are used to differentiate various types of functions, including polynomial, rational, trigonometric, and exponential functions.
#
# In summary, differentiation is a fundamental concept in calculus that measures the rate of change of a function with respect to its input. It has numerous applications in various fields and is used to describe rates of change, slopes of curves, and optimization problems.

# %%
grade = "10"
subjects = ["english", "english2", "history", "math"]
query = "What did Lencho ask God"

for chunk in generate(template, grade, subjects, query):
    print(chunk, end="", flush=True)
# Out:
# According to the story, Lencho asked God for 100 pesos (money) in his first letter, but only received 70 pesos in response. In his second letter, he asked God to send him the remaining 30 pesos, and also requested that it not be sent through the mail because the post office employees are "crooks".
